# %% [markdown]
# # CAPSTONE PROJECT

# %% [markdown]
# ## Credit Card Default

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns # for making plots with seaborn
color = sns.color_palette()
import sklearn.metrics as metrics

import warnings
warnings.filterwarnings("ignore")


#import os 
import scipy.stats as stats

from sklearn.model_selection import train_test_split

import statsmodels.api as sm

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.tree import DecisionTreeClassifier

from sklearn import metrics
from sklearn import tree

from sklearn.preprocessing import scale
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# # NOTES I

# %% [markdown]
# ### Importing the dataset

# %%
credit = pd.read_excel('PD_modelling_dataset.xlsx', engine='openpyxl')

# %%
credit.head(10)
# Out:
#       userid  default  acct_amt_added_12_24m  acct_days_in_dc_12_24m  \
# 0 4567129.00     0.00                   0.00                    0.00
# 1 2635118.00     0.00                   0.00                    0.00
# 2 4804232.00     0.00                   0.00                    0.00
# 3 1442693.00     0.00                   0.00                     nan
# 4 4575322.00     0.00                   0.00                    0.00
# 5 1534132.00     0.00                   0.00                    0.00
# 6 1179589.00     0.00                   0.00                    0.00
# 7 2182448.00     0.00               57229.00                    0.00
# 8 1661559.00     0.00              148922.00                    0.00
# 9 4628751.00     0.00                   0.00                    0.00
#
#    acct_days_in_rem_12_24m  acct_days_in_term_12_24m  \
# 0                     0.00                      0.00
# 1                     0.00                      0.00
# 2                     0.00                      0.00
# 3                      nan                       nan
# 4                     0.00                      0.00
# 5                     0.00                      0.00
# 6                   142.00                      0.00
# 7                     0.00                      0.00
# 8                    47.00                      0.00
# 9                     0.00                      0.00
#
#    acct_incoming_debt_vs_paid_0_24m  acct_status  acct_worst_status_0_3m  \
# 0                              0.00         1.00                    1.00
# 1                               nan         1.00                    1.00
# 2                               nan          nan                     nan
# 3                               nan          nan                     nan
# 4                               nan          nan                     nan
# 5                               nan          nan                     nan
# 6                              0.00         1.00                    2.00
# 7                              0.23         1.00                    1.00
# 8                              0.97         1.00                    2.00
# 9                               nan          nan                     nan
#
#    acct_worst_status_12_24m  ...  num_arch_ok_12_24m  num_arch_rem_0_12m  \
# 0                       nan  ...               14.00                0.00
# 1                      1.00  ...               19.00                3.00
# 2                       nan  ...                0.00                3.00
# 3                       nan  ...               21.00                0.00
# 4                       nan  ...                0.00                0.00
# 5                       nan  ...                0.00                0.00
# 6                      2.00  ...                 nan                 nan
# 7                      1.00  ...              257.00                0.00
# 8                      2.00  ...                2.00                3.00
# 9                       nan  ...               10.00                0.00
#
#    status_max_archived_0_6_months  status_max_archived_0_12_months  \
# 0                            1.00                             1.00
# 1                            1.00                             2.00
# 2                            1.00                             2.00
# 3                            1.00                             1.00
# 4                            1.00                             1.00
# 5                            0.00                             0.00
# 6                             nan                              nan
# 7                            1.00                             1.00
# 8                            2.00                             2.00
# 9                            1.00                             1.00
#
#    status_max_archived_0_24_months recovery_debt sum_capital_paid_acct_0_12m  \
# 0                             1.00          0.00                        0.00
# 1                             2.00          0.00                        0.00
# 2                             2.00          0.00                        0.00
# 3                             1.00          0.00                        0.00
# 4                             1.00          0.00                        0.00
# 5                             0.00          0.00                        0.00
# 6                              nan           nan                         nan
# 7                             1.00          0.00                    42206.00
# 8                             2.00          0.00                   104643.00
# 9                             1.00          0.00                        0.00
#
#    sum_capital_paid_acct_12_24m  sum_paid_inv_0_12m  time_hours
# 0                          0.00           178839.00        9.65
# 1                          0.00            49014.00       13.18
# 2                          0.00           124839.00       11.56
# 3                          0.00           324676.00       15.75
# 4                          0.00             7100.00       12.70
# 5                          0.00                0.00       18.33
# 6                           nan                 nan         nan
# 7                      35336.00           457257.00       12.19
# 8                      32381.00            24390.00       21.41
# 9                          0.00            78620.00       13.34
#
# [10 rows x 36 columns]

# %% [markdown]
# ### Checking last 5 rows

# %%
credit.tail(10)
# Out:
#           userid  default  acct_amt_added_12_24m  acct_days_in_dc_12_24m  \
# 99969 3403106.00      nan                   0.00                  365.00
# 99970 3990080.00      nan               88405.00                    0.00
# 99971 3115649.00      nan                   0.00                    0.00
# 99972 1744943.00      nan                   0.00                    0.00
# 99973 4333001.00      nan               45671.00                    0.00
# 99974 4648093.00      nan               56102.00                    0.00
# 99975 1247657.00      nan                   0.00                    0.00
# 99976        nan      nan                    nan                     nan
# 99977        nan      nan                    nan                     nan
# 99978       0.00 10000.00                   0.00                11836.00
#
#        acct_days_in_rem_12_24m  acct_days_in_term_12_24m  \
# 99969                     0.00                      0.00
# 99970                    15.00                      0.00
# 99971                     0.00                      0.00
# 99972                     0.00                      0.00
# 99973                    20.00                      0.00
# 99974                     0.00                      0.00
# 99975                     0.00                      0.00
# 99976                      nan                       nan
# 99977                      nan                       nan
# 99978                 11836.00                  11836.00
#
#        acct_incoming_debt_vs_paid_0_24m  acct_status  acct_worst_status_0_3m  \
# 99969                              0.37         1.00                    1.00
# 99970                              0.67         2.00                    2.00
# 99971                               nan         1.00                    1.00
# 99972                              0.00         1.00                    1.00
# 99973                              0.71         2.00                    2.00
# 99974                              0.06         1.00                    2.00
# 99975                               nan         1.00                    1.00
# 99976                               nan          nan                     nan
# 99977                               nan          nan                     nan
# 99978                          59315.00     54373.00                54373.00
#
#        acct_worst_status_12_24m  ...  num_arch_ok_12_24m  num_arch_rem_0_12m  \
# 99969                      4.00  ...                 nan                 nan
# 99970                      2.00  ...                2.00                0.00
# 99971                       nan  ...                2.00                0.00
# 99972                       nan  ...                3.00                0.00
# 99973                      2.00  ...                0.00                0.00
# 99974                      1.00  ...                1.00                0.00
# 99975                       nan  ...                2.00                1.00
# 99976                       nan  ...                 nan                 nan
# 99977                       nan  ...                 nan                 nan
# 99978                  66761.00  ...                0.00                0.00
#
#        status_max_archived_0_6_months  status_max_archived_0_12_months  \
# 99969                             nan                              nan
# 99970                            0.00                             0.00
# 99971                            1.00                             1.00
# 99972                            0.00                             1.00
# 99973                            0.00                             0.00
# 99974                            1.00                             1.00
# 99975                            2.00                             2.00
# 99976                             nan                              nan
# 99977                             nan                              nan
# 99978                            0.00                             0.00
#
#        status_max_archived_0_24_months recovery_debt  \
# 99969                              nan           nan
# 99970                             1.00          0.00
# 99971                             1.00          0.00
# 99972                             1.00          0.00
# 99973                             0.00          0.00
# 99974                             1.00          0.00
# 99975                             2.00          0.00
# 99976                              nan           nan
# 99977                              nan           nan
# 99978                             0.00          0.00
#
#       sum_capital_paid_acct_0_12m  sum_capital_paid_acct_12_24m  \
# 99969                         nan                           nan
# 99970                    28870.00                      25771.00
# 99971                        0.00                          0.00
# 99972                     7948.00                          0.00
# 99973                    17447.00                      19627.00
# 99974                    18339.00                      56180.00
# 99975                        0.00                          0.00
# 99976                         nan                           nan
# 99977                         nan                           nan
# 99978                        0.00                          0.00
#
#        sum_paid_inv_0_12m  time_hours
# 99969                 nan         nan
# 99970                0.00        9.06
# 99971            60127.00       10.77
# 99972             4740.00       21.71
# 99973             3100.00        2.19
# 99974            34785.00        9.73
# 99975            30602.00       11.59
# 99976                 nan         nan
# 99977                 nan         nan
# 99978                0.00        0.00
#
# [10 rows x 36 columns]

# %% [markdown]
# ### Now, let us check the number of rows and the number of columns

# %%
print('Total number of rows in the dataset:',credit.shape[0])
print('Total number of columns in the dataset:',credit.shape[1])
# Out:
# Total number of rows in the dataset: 99979
# Total number of columns in the dataset: 36

# %%
credit.columns
# Out:
# Index(['userid', 'default', 'acct_amt_added_12_24m', 'acct_days_in_dc_12_24m',
#        'acct_days_in_rem_12_24m', 'acct_days_in_term_12_24m',
#        'acct_incoming_debt_vs_paid_0_24m', 'acct_status',
#        'acct_worst_status_0_3m', 'acct_worst_status_12_24m',
#        'acct_worst_status_3_6m', 'acct_worst_status_6_12m', 'age',
#        'avg_payment_span_0_12m', 'avg_payment_span_0_3m', 'merchant_category',
#        'merchant_group', 'has_paid', 'max_paid_inv_0_12m',
#        'max_paid_inv_0_24m', 'name_in_email',
#        'num_active_div_by_paid_inv_0_12m', 'num_active_inv',
#        'num_arch_dc_0_12m', 'num_arch_dc_12_24m', 'num_arch_ok_0_12m',
#        'num_arch_ok_12_24m', 'num_arch_rem_0_12m',
#        'status_max_archived_0_6_months', 'status_max_archived_0_12_months',
#        'status_max_archived_0_24_months', 'recovery_debt',
#        'sum_capital_paid_acct_0_12m', 'sum_capital_paid_acct_12_24m',
#        'sum_paid_inv_0_12m', 'time_hours'],
#       dtype='object')

# %% [markdown]
# ### Checking basic info about all columns

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99979 entries, 0 to 99978
# Data columns (total 36 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   userid                            99977 non-null  float64
#  1   default                           89977 non-null  float64
#  2   acct_amt_added_12_24m             99977 non-null  float64
#  3   acct_days_in_dc_12_24m            88141 non-null  float64
#  4   acct_days_in_rem_12_24m           88141 non-null  float64
#  5   acct_days_in_term_12_24m          88141 non-null  float64
#  6   acct_incoming_debt_vs_paid_0_24m  40662 non-null  float64
#  7   acct_status                       45604 non-null  float64
#  8   acct_worst_status_0_3m            45604 non-null  float64
#  9   acct_worst_status_12_24m          33216 non-null  float64
#  10  acct_worst_status_3_6m            42275 non-null  float64
#  11  acct_worst_status_6_12m           39627 non-null  float64
#  12  age                               99977 non-null  float64
#  13  avg_payment_span_0_12m            76141 non-null  float64
#  14  avg_payment_span_0_3m             50672 non-null  float64
#  15  merchant_category                 99977 non-null  object
#  16  merchant_group                    99968 non-null  object
#  17  has_paid                          88943 non-null  float64
#  18  max_paid_inv_0_12m                88943 non-null  float64
#  19  max_paid_inv_0_24m                88943 non-null  float64
#  20  name_in_email                     88943 non-null  object
#  21  num_active_div_by_paid_inv_0_12m  70052 non-null  float64
#  22  num_active_inv                    88943 non-null  float64
#  23  num_arch_dc_0_12m                 88943 non-null  float64
#  24  num_arch_dc_12_24m                88943 non-null  float64
#  25  num_arch_ok_0_12m                 88943 non-null  float64
#  26  num_arch_ok_12_24m                88943 non-null  float64
#  27  num_arch_rem_0_12m                88943 non-null  float64
#  28  status_max_archived_0_6_months    88943 non-null  float64
#  29  status_max_archived_0_12_months   88943 non-null  float64
#  30  status_max_archived_0_24_months   88943 non-null  float64
#  31  recovery_debt                     88943 non-null  float64
#  32  sum_capital_paid_acct_0_12m       88943 non-null  float64
#  33  sum_capital_paid_acct_12_24m      88943 non-null  float64
#  34  sum_paid_inv_0_12m                88943 non-null  float64
#  35  time_hours                        88943 non-null  float64
# dtypes: float64(33), object(3)
# memory usage: 27.5+ MB

# %% [markdown]
# ### Checking for duplicates:

# %%
if credit.duplicated().sum()==0:
    print('There are no duplicate rows in the dataset.')
else:
    print('Total number of duplicate rows in the dataset :',credit.duplicated().sum())
# Out:
# Total number of duplicate rows in the dataset : 1

# %%
credit.drop_duplicates(inplace=True)

# %%
if credit.duplicated().sum()==0:
    print('There are no duplicate rows in the dataset.')
else:
    print('Total number of duplicate rows in the dataset :',credit.duplicated().sum())
# Out:
# There are no duplicate rows in the dataset.

# %% [markdown]
# ### Now, checking 5 point summary stats of the data

# %% [markdown]
# #### a) For categorical columns:

# %%
cat = credit.select_dtypes(include=['object']).columns
credit[cat].describe().T
# Out:
#                    count unique                        top   freq
# merchant_category  99977     58  Diversified entertainment  38614
# merchant_group     99968     13              Entertainment  48779
# name_in_email      88943      9                        F+L  35822

# %% [markdown]
# #### b) For continuous numeric columns:

# %%
continuous = credit.select_dtypes(include=['float64']).columns
credit[continuous].describe().T
# Out:
#                                     count       mean        std  min  \
# userid                           99977.00 2998946.73 1154210.60 0.00
# default                          89977.00       0.13      33.34 0.00
# acct_amt_added_12_24m            99977.00   12255.03   35481.33 0.00
# acct_days_in_dc_12_24m           88141.00       0.36      40.29 0.00
# acct_days_in_rem_12_24m          88141.00       5.18      45.94 0.00
# acct_days_in_term_12_24m         88141.00       0.42      39.97 0.00
# acct_incoming_debt_vs_paid_0_24m 40662.00       2.79     295.33 0.00
# acct_status                      45604.00       2.23     254.61 1.00
# acct_worst_status_0_3m           45604.00       2.37     254.61 1.00
# acct_worst_status_12_24m         33216.00       3.35     366.30 1.00
# acct_worst_status_3_6m           42275.00       2.55     280.63 1.00
# acct_worst_status_6_12m          39627.00       2.78     303.16 1.00
# age                              99977.00      36.02      13.00 0.00
# avg_payment_span_0_12m           76141.00      18.28      87.25 0.00
# avg_payment_span_0_3m            50672.00      15.96     219.21 0.00
# has_paid                         88943.00       0.87       0.34 0.00
# max_paid_inv_0_12m               88943.00    9362.71   13672.42 0.00
# max_paid_inv_0_24m               88943.00   11419.61   15431.71 0.00
# num_active_div_by_paid_inv_0_12m 70052.00       0.38      71.37 0.00
# num_active_inv                   88943.00       0.63       1.61 0.00
# num_arch_dc_0_12m                88943.00       0.06       0.38 0.00
# num_arch_dc_12_24m               88943.00       0.06       0.36 0.00
# num_arch_ok_0_12m                88943.00       7.79      16.74 0.00
# num_arch_ok_12_24m               88943.00       6.85      16.07 0.00
# num_arch_rem_0_12m               88943.00       0.48       1.40 0.00
# status_max_archived_0_6_months   88943.00       0.82       0.72 0.00
# status_max_archived_0_12_months  88943.00       1.07       0.78 0.00
# status_max_archived_0_24_months  88943.00       1.25       0.82 0.00
# recovery_debt                    88943.00       3.60     116.21 0.00
# sum_capital_paid_acct_0_12m      88943.00   10860.26   26630.62 0.00
# sum_capital_paid_acct_12_24m     88943.00    6614.95   19243.81 0.00
# sum_paid_inv_0_12m               88943.00   41035.91   94596.42 0.00
# time_hours                       88943.00      15.34       5.03 0.00
#
#                                         25%        50%        75%        max
# userid                           2000260.00 2998815.00 4000633.00 4999868.00
# default                                0.00       0.00       0.00   10000.00
# acct_amt_added_12_24m                  0.00       0.00    4937.00 1128775.00
# acct_days_in_dc_12_24m                 0.00       0.00       0.00   11836.00
# acct_days_in_rem_12_24m                0.00       0.00       0.00   11836.00
# acct_days_in_term_12_24m               0.00       0.00       0.00   11836.00
# acct_incoming_debt_vs_paid_0_24m       0.00       0.15       0.66   59315.00
# acct_status                            1.00       1.00       1.00   54373.00
# acct_worst_status_0_3m                 1.00       1.00       1.00   54373.00
# acct_worst_status_12_24m               1.00       1.00       2.00   66761.00
# acct_worst_status_3_6m                 1.00       1.00       1.00   57702.00
# acct_worst_status_6_12m                1.00       1.00       1.00   60350.00
# age                                   25.00      34.00      45.00     100.00
# avg_payment_span_0_12m                10.80      14.91      21.00   23836.00
# avg_payment_span_0_3m                  8.40      13.00      18.29   49305.00
# has_paid                               1.00       1.00       1.00       1.00
# max_paid_inv_0_12m                  2387.50    6170.00   11400.00  279000.00
# max_paid_inv_0_24m                  3685.00    7720.00   13865.00  538500.00
# num_active_div_by_paid_inv_0_12m       0.00       0.00       0.10   18891.00
# num_active_inv                         0.00       0.00       1.00      47.00
# num_arch_dc_0_12m                      0.00       0.00       0.00      17.00
# num_arch_dc_12_24m                     0.00       0.00       0.00      13.00
# num_arch_ok_0_12m                      0.00       3.00       8.00     261.00
# num_arch_ok_12_24m                     0.00       2.00       7.00     313.00
# num_arch_rem_0_12m                     0.00       0.00       0.00      42.00
# status_max_archived_0_6_months         0.00       1.00       1.00       3.00
# status_max_archived_0_12_months        1.00       1.00       2.00       5.00
# status_max_archived_0_24_months        1.00       1.00       2.00       5.00
# recovery_debt                          0.00       0.00       0.00   16411.00
# sum_capital_paid_acct_0_12m            0.00       0.00    8959.50  571475.00
# sum_capital_paid_acct_12_24m           0.00       0.00     102.50  341859.00
# sum_paid_inv_0_12m                  3395.50   17057.00   45739.00 2962870.00
# time_hours                            11.63      15.81      19.55      24.00

# %% [markdown]
# #### Dropping the last row

# %%
credit.drop(99978, inplace = True)
credit.tail()
# Out:
#           userid  default  acct_amt_added_12_24m  acct_days_in_dc_12_24m  \
# 99972 1744943.00      nan                   0.00                    0.00
# 99973 4333001.00      nan               45671.00                    0.00
# 99974 4648093.00      nan               56102.00                    0.00
# 99975 1247657.00      nan                   0.00                    0.00
# 99976        nan      nan                    nan                     nan
#
#        acct_days_in_rem_12_24m  acct_days_in_term_12_24m  \
# 99972                     0.00                      0.00
# 99973                    20.00                      0.00
# 99974                     0.00                      0.00
# 99975                     0.00                      0.00
# 99976                      nan                       nan
#
#        acct_incoming_debt_vs_paid_0_24m  acct_status  acct_worst_status_0_3m  \
# 99972                              0.00         1.00                    1.00
# 99973                              0.71         2.00                    2.00
# 99974                              0.06         1.00                    2.00
# 99975                               nan         1.00                    1.00
# 99976                               nan          nan                     nan
#
#        acct_worst_status_12_24m  ...  num_arch_ok_12_24m  num_arch_rem_0_12m  \
# 99972                       nan  ...                3.00                0.00
# 99973                      2.00  ...                0.00                0.00
# 99974                      1.00  ...                1.00                0.00
# 99975                       nan  ...                2.00                1.00
# 99976                       nan  ...                 nan                 nan
#
#        status_max_archived_0_6_months  status_max_archived_0_12_months  \
# 99972                            0.00                             1.00
# 99973                            0.00                             0.00
# 99974                            1.00                             1.00
# 99975                            2.00                             2.00
# 99976                             nan                              nan
#
#        status_max_archived_0_24_months recovery_debt  \
# 99972                             1.00          0.00
# 99973                             0.00          0.00
# 99974                             1.00          0.00
# 99975                             2.00          0.00
# 99976                              nan           nan
#
#       sum_capital_paid_acct_0_12m  sum_capital_paid_acct_12_24m  \
# 99972                     7948.00                          0.00
# 99973                    17447.00                      19627.00
# 99974                    18339.00                      56180.00
# 99975                        0.00                          0.00
# 99976                         nan                           nan
#
#        sum_paid_inv_0_12m  time_hours
# 99972             4740.00       21.71
# 99973             3100.00        2.19
# 99974            34785.00        9.73
# 99975            30602.00       11.59
# 99976                 nan         nan
#
# [5 rows x 36 columns]

# %% [markdown]
# #### Checking the 5 point summary for continuous variables again

# %%
continuous = credit.select_dtypes(include=['float64']).columns
credit[continuous].describe().T
# Out:
#                                     count       mean        std        min  \
# userid                           99976.00 2998976.73 1154177.40 1000053.00
# default                          89976.00       0.01       0.12       0.00
# acct_amt_added_12_24m            99976.00   12255.15   35481.48       0.00
# acct_days_in_dc_12_24m           88140.00       0.22       5.81       0.00
# acct_days_in_rem_12_24m          88140.00       5.04      22.86       0.00
# acct_days_in_term_12_24m         88140.00       0.29       2.93       0.00
# acct_incoming_debt_vs_paid_0_24m 40661.00       1.33      26.48       0.00
# acct_status                      45603.00       1.04       0.20       1.00
# acct_worst_status_0_3m           45603.00       1.17       0.42       1.00
# acct_worst_status_12_24m         33215.00       1.34       0.58       1.00
# acct_worst_status_3_6m           42274.00       1.19       0.44       1.00
# acct_worst_status_6_12m          39626.00       1.25       0.51       1.00
# age                              99976.00      36.02      13.00      18.00
# avg_payment_span_0_12m           76140.00      17.97      12.75       0.00
# avg_payment_span_0_3m            50671.00      14.99      10.30       0.00
# has_paid                         88942.00       0.87       0.34       0.00
# max_paid_inv_0_12m               88942.00    9362.82   13672.46       0.00
# max_paid_inv_0_24m               88942.00   11419.73   15431.75       0.00
# num_active_div_by_paid_inv_0_12m 70051.00       0.11       0.29       0.00
# num_active_inv                   88942.00       0.63       1.61       0.00
# num_arch_dc_0_12m                88942.00       0.06       0.38       0.00
# num_arch_dc_12_24m               88942.00       0.06       0.36       0.00
# num_arch_ok_0_12m                88942.00       7.79      16.74       0.00
# num_arch_ok_12_24m               88942.00       6.85      16.07       0.00
# num_arch_rem_0_12m               88942.00       0.48       1.40       0.00
# status_max_archived_0_6_months   88942.00       0.82       0.72       0.00
# status_max_archived_0_12_months  88942.00       1.07       0.78       0.00
# status_max_archived_0_24_months  88942.00       1.25       0.82       0.00
# recovery_debt                    88942.00       3.60     116.21       0.00
# sum_capital_paid_acct_0_12m      88942.00   10860.38   26630.74       0.00
# sum_capital_paid_acct_12_24m     88942.00    6615.02   19243.90       0.00
# sum_paid_inv_0_12m               88942.00   41036.37   94596.85       0.00
# time_hours                       88942.00      15.34       5.03       0.00
#
#                                         25%        50%        75%        max
# userid                           2000266.75 2998832.00 4000640.75 4999868.00
# default                                0.00       0.00       0.00       1.00
# acct_amt_added_12_24m                  0.00       0.00    4937.25 1128775.00
# acct_days_in_dc_12_24m                 0.00       0.00       0.00     365.00
# acct_days_in_rem_12_24m                0.00       0.00       0.00     365.00
# acct_days_in_term_12_24m               0.00       0.00       0.00      97.00
# acct_incoming_debt_vs_paid_0_24m       0.00       0.15       0.66    3914.00
# acct_status                            1.00       1.00       1.00       4.00
# acct_worst_status_0_3m                 1.00       1.00       1.00       4.00
# acct_worst_status_12_24m               1.00       1.00       2.00       4.00
# acct_worst_status_3_6m                 1.00       1.00       1.00       4.00
# acct_worst_status_6_12m                1.00       1.00       1.00       4.00
# age                                   25.00      34.00      45.00     100.00
# avg_payment_span_0_12m                10.80      14.91      21.00     260.00
# avg_payment_span_0_3m                  8.40      13.00      18.29      87.00
# has_paid                               1.00       1.00       1.00       1.00
# max_paid_inv_0_12m                  2390.00    6170.00   11400.00  279000.00
# max_paid_inv_0_24m                  3685.00    7720.00   13865.00  538500.00
# num_active_div_by_paid_inv_0_12m       0.00       0.00       0.10       9.00
# num_active_inv                         0.00       0.00       1.00      47.00
# num_arch_dc_0_12m                      0.00       0.00       0.00      17.00
# num_arch_dc_12_24m                     0.00       0.00       0.00      13.00
# num_arch_ok_0_12m                      0.00       3.00       8.00     261.00
# num_arch_ok_12_24m                     0.00       2.00       7.00     313.00
# num_arch_rem_0_12m                     0.00       0.00       0.00      42.00
# status_max_archived_0_6_months         0.00       1.00       1.00       3.00
# status_max_archived_0_12_months        1.00       1.00       2.00       5.00
# status_max_archived_0_24_months        1.00       1.00       2.00       5.00
# recovery_debt                          0.00       0.00       0.00   16411.00
# sum_capital_paid_acct_0_12m            0.00       0.00    8960.75  571475.00
# sum_capital_paid_acct_12_24m           0.00       0.00     102.75  341859.00
# sum_paid_inv_0_12m                  3396.50   17057.50   45739.50 2962870.00
# time_hours                            11.63      15.81      19.55      24.00

# %% [markdown]
# ----

# %% [markdown]
# ----

# %% [markdown]
# # 3) EDA (Exploratory data analysis)

# %% [markdown]
# ## a) Univariate analysis

# %% [markdown]
# #### Checking the dataset variables for value counts and discripancies:

# %%
sns.barplot(data=credit,x='has_paid',y='acct_amt_added_12_24m')
# Out:
# <AxesSubplot:xlabel='has_paid', ylabel='acct_amt_added_12_24m'>

# %%
sns.histplot(data=credit,x='status_max_archived_0_24_months')
# Out:
# <AxesSubplot:xlabel='status_max_archived_0_24_months', ylabel='Count'>

# %% [markdown]
# #### Distribution of data for categorical variables

# %% [markdown]
# * Looking at the value counts, the variables that look categorical in nature are as follows

# %%
sns.countplot(data=credit,x='default')
# Out:
# <AxesSubplot:xlabel='default', ylabel='count'>

# %%
sns.histplot(data=credit,x='acct_days_in_dc_12_24m')
# Out:
# <AxesSubplot:xlabel='acct_days_in_dc_12_24m', ylabel='Count'>

# %%
sns.countplot(data=credit,x='acct_status')
# Out:
# <AxesSubplot:xlabel='acct_status', ylabel='count'>

# %%
sns.countplot(data=credit,x='status_max_archived_0_24_months')
# Out:
# <AxesSubplot:xlabel='status_max_archived_0_24_months', ylabel='count'>

# %%
sns.countplot(data=credit,x='status_max_archived_0_12_months')
# Out:
# <AxesSubplot:xlabel='status_max_archived_0_12_months', ylabel='count'>

# %%
sns.countplot(data=credit,x='has_paid')
# Out:
# <AxesSubplot:xlabel='has_paid', ylabel='count'>

# %%
plt.figure(figsize=(25,40))
sns.countplot(data=credit,y='merchant_category',order=credit['merchant_category'].value_counts().sort_values(ascending=False).index)
plt.title('barplot of merchant_category', fontsize= 30)
plt.ylabel('merchant_category', fontsize=20)
plt.xlabel('Count', fontsize=20) 
plt.xticks(fontsize=20) 
plt.yticks(fontsize=20) 
plt.tight_layout()

# %%
plt.figure(figsize=(8,8))
sns.countplot(data=credit, x='merchant_group', order=credit['merchant_group'].value_counts().sort_values(ascending=False).index)
#plt.title('barplot of merchant_group', fontsize= 20)
plt.xticks(rotation = 90) 
#plt.yticks(fontsize=15) 
plt.tight_layout()

# %% [markdown]
# #### Distribution of data for continuous variables

# %% [markdown]
# #### There seems to be some abnormalities in the dataset:
# * It's worth noting that the second last row has all the values missing, hence we will look for rows with a lot of missing values and drop such rows since imputing large amounts of missing values row-wise will distort our dataset.
# * Variable "acct_status" should only have 0 and 1 as values as per the data dictionary, but in the actual dataset it has 1,2,3 and 4 as values. We need to find the reasoning behind this nomenclature or else drop this variable too if the logic cannot be found.
# * we will also drop such variables which are not required for our model building namely 'userid', 'name_in_email'.

# %% [markdown]
# ---

# %% [markdown]
# ## b) Bivariate and Multivariate analysis

# %% [markdown]
# #### Bivariate Analysis

# %%
sns.barplot(data=credit,x='status_max_archived_0_24_months',y='age')
# Out:
# <AxesSubplot:xlabel='status_max_archived_0_24_months', ylabel='age'>

# %%
sns.scatterplot(data=credit,x='age',y='recovery_debt')
# Out:
# <AxesSubplot:xlabel='age', ylabel='recovery_debt'>

# %%
sns.barplot(data=credit,y='age',x='num_arch_dc_12_24m')
# Out:
# <AxesSubplot:xlabel='num_arch_dc_12_24m', ylabel='age'>

# %%
sns.countplot(data=credit, x='has_paid', hue='default')
# Out:
# <AxesSubplot:xlabel='has_paid', ylabel='count'>

# %% [markdown]
# * Since defaulters make only 1% of the dataset, bar plot comparison of categorical variables with the target variable is unlikely to produce any meaningful insights.
# * For checking the correlation between independent variables we will be using heatmap instead of scatterplots, as they are better at quantifying the correlation.
# * We are also looking at the pairplot to have a basic idea about the distribution of all the variables with respect to each other, this gives us a visual representation of the correlation between the variables as opposed to heatmap where we only get numerical representation of the correlation between variables.
# * But due to the dataset having large number of numerical variables, the pair plot becomes illegible as it produces all the possible combination of correlated variables. Still, it's okay enough for getting a bird's eye view on the numerical variables. Another downside of pairplots is that they take a lot of time to get executed especially if the dataset is large.
# * Due to these reasons we use heatmaps as our main tool to check correlation between the independent continuous variables.

# %% [markdown]
# #### Multivariate Analysis

# %% [markdown]
# #### Heat map

# %%
corrmat = credit.corr()
plt.figure(figsize=(20,20))
hm = sns.heatmap(corrmat, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10},  cmap="crest")
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# ## c) Removal of unwanted variables

# %%
credit.columns
# Out:
# Index(['userid', 'default', 'acct_amt_added_12_24m', 'acct_days_in_dc_12_24m',
#        'acct_days_in_rem_12_24m', 'acct_days_in_term_12_24m',
#        'acct_incoming_debt_vs_paid_0_24m', 'acct_status',
#        'acct_worst_status_0_3m', 'acct_worst_status_12_24m',
#        'acct_worst_status_3_6m', 'acct_worst_status_6_12m', 'age',
#        'avg_payment_span_0_12m', 'avg_payment_span_0_3m', 'merchant_category',
#        'merchant_group', 'has_paid', 'max_paid_inv_0_12m',
#        'max_paid_inv_0_24m', 'name_in_email',
#        'num_active_div_by_paid_inv_0_12m', 'num_active_inv',
#        'num_arch_dc_0_12m', 'num_arch_dc_12_24m', 'num_arch_ok_0_12m',
#        'num_arch_ok_12_24m', 'num_arch_rem_0_12m',
#        'status_max_archived_0_6_months', 'status_max_archived_0_12_months',
#        'status_max_archived_0_24_months', 'recovery_debt',
#        'sum_capital_paid_acct_0_12m', 'sum_capital_paid_acct_12_24m',
#        'sum_paid_inv_0_12m', 'time_hours'],
#       dtype='object')

# %%
credit = credit.drop(['userid', 'name_in_email'], axis = 1)

# %%
credit.shape
# Out:
# (99977, 34)

# %%
credit.columns
# Out:
# Index(['default', 'acct_amt_added_12_24m', 'acct_days_in_dc_12_24m',
#        'acct_days_in_rem_12_24m', 'acct_days_in_term_12_24m',
#        'acct_incoming_debt_vs_paid_0_24m', 'acct_status',
#        'acct_worst_status_0_3m', 'acct_worst_status_12_24m',
#        'acct_worst_status_3_6m', 'acct_worst_status_6_12m', 'age',
#        'avg_payment_span_0_12m', 'avg_payment_span_0_3m', 'merchant_category',
#        'merchant_group', 'has_paid', 'max_paid_inv_0_12m',
#        'max_paid_inv_0_24m', 'num_active_div_by_paid_inv_0_12m',
#        'num_active_inv', 'num_arch_dc_0_12m', 'num_arch_dc_12_24m',
#        'num_arch_ok_0_12m', 'num_arch_ok_12_24m', 'num_arch_rem_0_12m',
#        'status_max_archived_0_6_months', 'status_max_archived_0_12_months',
#        'status_max_archived_0_24_months', 'recovery_debt',
#        'sum_capital_paid_acct_0_12m', 'sum_capital_paid_acct_12_24m',
#        'sum_paid_inv_0_12m', 'time_hours'],
#       dtype='object')

# %% [markdown]
# ----

# %% [markdown]
# ## d) Missing Value treatment

# %% [markdown]
# #### Checking for missing values in the dataset

# %%
missing = pd.DataFrame([credit.columns, credit.isnull().sum(), credit.isnull().sum()/credit.index.size*100])
missing = missing.T
missing.columns = ['Column_name','Missing_values','Percentage_missing_values']
missing
# Out:
#                          Column_name Missing_values Percentage_missing_values
# 0                            default          10001                     10.00
# 1              acct_amt_added_12_24m              1                      0.00
# 2             acct_days_in_dc_12_24m          11837                     11.84
# 3            acct_days_in_rem_12_24m          11837                     11.84
# 4           acct_days_in_term_12_24m          11837                     11.84
# 5   acct_incoming_debt_vs_paid_0_24m          59316                     59.33
# 6                        acct_status          54374                     54.39
# 7             acct_worst_status_0_3m          54374                     54.39
# 8           acct_worst_status_12_24m          66762                     66.78
# 9             acct_worst_status_3_6m          57703                     57.72
# 10           acct_worst_status_6_12m          60351                     60.36
# 11                               age              1                      0.00
# 12            avg_payment_span_0_12m          23837                     23.84
# 13             avg_payment_span_0_3m          49306                     49.32
# 14                 merchant_category              1                      0.00
# 15                    merchant_group             10                      0.01
# 16                          has_paid          11035                     11.04
# 17                max_paid_inv_0_12m          11035                     11.04
# 18                max_paid_inv_0_24m          11035                     11.04
# 19  num_active_div_by_paid_inv_0_12m          29926                     29.93
# 20                    num_active_inv          11035                     11.04
# 21                 num_arch_dc_0_12m          11035                     11.04
# 22                num_arch_dc_12_24m          11035                     11.04
# 23                 num_arch_ok_0_12m          11035                     11.04
# 24                num_arch_ok_12_24m          11035                     11.04
# 25                num_arch_rem_0_12m          11035                     11.04
# 26    status_max_archived_0_6_months          11035                     11.04
# 27   status_max_archived_0_12_months          11035                     11.04
# 28   status_max_archived_0_24_months          11035                     11.04
# 29                     recovery_debt          11035                     11.04
# 30       sum_capital_paid_acct_0_12m          11035                     11.04
# 31      sum_capital_paid_acct_12_24m          11035                     11.04
# 32                sum_paid_inv_0_12m          11035                     11.04
# 33                        time_hours          11035                     11.04

# %% [markdown]
# #### Visually inspecting the missing values in the dataset using heatmap (white bars show missing values)

# %%
plt.figure(figsize = (22,10))
plt.xticks(fontsize=15)
sns.heatmap(credit.isnull(), cbar=False, cmap = 'Paired', yticklabels = False)
plt.show()

# %% [markdown]
# #### Checking the proportion of missing values

# %%
credit.size
# Out:
# 3399218

# %%
credit.isnull().sum().sum()
# Out:
# 689069

# %%
(689103/3399286)*100
# Out:
# 20.271992412524277

# %% [markdown]
# * Total %age of missing values is around 20% which is a lot. Therefore we should be quite careful as to how we are going to treat these missing values.

# %% [markdown]
# * There are a lot of missing values in the dataset.
# * Among them we should drop the variables which have atleast 30% of the data as missing values, as imputing such large number of missing values will lead to what we call an Analyst bias.
# * It refers to an approach related bias, since missing values imputation differ from analyst to analyst and there is no sure shot way to do it.

# %% [markdown]
# #### After dropping the variables with more than 30% missing values, we are left with 24 independent variables.

# %%
missing[missing['Percentage_missing_values']>29]
# Out:
#                          Column_name Missing_values Percentage_missing_values
# 5   acct_incoming_debt_vs_paid_0_24m          59316                     59.33
# 6                        acct_status          54374                     54.39
# 7             acct_worst_status_0_3m          54374                     54.39
# 8           acct_worst_status_12_24m          66762                     66.78
# 9             acct_worst_status_3_6m          57703                     57.72
# 10           acct_worst_status_6_12m          60351                     60.36
# 13             avg_payment_span_0_3m          49306                     49.32
# 19  num_active_div_by_paid_inv_0_12m          29926                     29.93

# %%
credit1 = credit.drop(['acct_incoming_debt_vs_paid_0_24m', 'acct_status','acct_worst_status_0_3m',
                       'acct_worst_status_12_24m','acct_worst_status_3_6m','acct_worst_status_6_12m',
                       'avg_payment_span_0_3m','num_active_div_by_paid_inv_0_12m'], axis = 1)

# %%
credit1.shape
# Out:
# (99977, 26)

# %% [markdown]
# #### imputing the remaining missing values

# %%
missing1 = (credit1.isnull().sum()/credit1.index.size)*100
missing1
# Out:
# default                           10.00
# acct_amt_added_12_24m              0.00
# acct_days_in_dc_12_24m            11.84
# acct_days_in_rem_12_24m           11.84
# acct_days_in_term_12_24m          11.84
# age                                0.00
# avg_payment_span_0_12m            23.84
# merchant_category                  0.00
# merchant_group                     0.01
# has_paid                          11.04
# max_paid_inv_0_12m                11.04
# max_paid_inv_0_24m                11.04
# num_active_inv                    11.04
# num_arch_dc_0_12m                 11.04
# num_arch_dc_12_24m                11.04
# num_arch_ok_0_12m                 11.04
# num_arch_ok_12_24m                11.04
# num_arch_rem_0_12m                11.04
# status_max_archived_0_6_months    11.04
# status_max_archived_0_12_months   11.04
# status_max_archived_0_24_months   11.04
# recovery_debt                     11.04
# sum_capital_paid_acct_0_12m       11.04
# sum_capital_paid_acct_12_24m      11.04
# sum_paid_inv_0_12m                11.04
# time_hours                        11.04
# dtype: float64

# %%
credit1.columns
# Out:
# Index(['default', 'acct_amt_added_12_24m', 'acct_days_in_dc_12_24m',
#        'acct_days_in_rem_12_24m', 'acct_days_in_term_12_24m', 'age',
#        'avg_payment_span_0_12m', 'merchant_category', 'merchant_group',
#        'has_paid', 'max_paid_inv_0_12m', 'max_paid_inv_0_24m',
#        'num_active_inv', 'num_arch_dc_0_12m', 'num_arch_dc_12_24m',
#        'num_arch_ok_0_12m', 'num_arch_ok_12_24m', 'num_arch_rem_0_12m',
#        'status_max_archived_0_6_months', 'status_max_archived_0_12_months',
#        'status_max_archived_0_24_months', 'recovery_debt',
#        'sum_capital_paid_acct_0_12m', 'sum_capital_paid_acct_12_24m',
#        'sum_paid_inv_0_12m', 'time_hours'],
#       dtype='object')

# %% [markdown]
# * Treating missing values in the categorical variables 'merchant_category' and 'merchant_group' with the respective mode values.

# %%
credit1['merchant_group'].fillna(credit1['merchant_group'].mode()[0], inplace=True)

# %%
credit1['merchant_category'].fillna(credit1['merchant_category'].mode()[0], inplace=True)

# %%
credit1.shape
# Out:
# (99977, 26)

# %%
missing1 = (credit1.isnull().sum()/credit1.index.size)*100
missing1
# Out:
# default                           10.00
# acct_amt_added_12_24m              0.00
# acct_days_in_dc_12_24m            11.84
# acct_days_in_rem_12_24m           11.84
# acct_days_in_term_12_24m          11.84
# age                                0.00
# avg_payment_span_0_12m            23.84
# merchant_category                  0.00
# merchant_group                     0.00
# has_paid                          11.04
# max_paid_inv_0_12m                11.04
# max_paid_inv_0_24m                11.04
# num_active_inv                    11.04
# num_arch_dc_0_12m                 11.04
# num_arch_dc_12_24m                11.04
# num_arch_ok_0_12m                 11.04
# num_arch_ok_12_24m                11.04
# num_arch_rem_0_12m                11.04
# status_max_archived_0_6_months    11.04
# status_max_archived_0_12_months   11.04
# status_max_archived_0_24_months   11.04
# recovery_debt                     11.04
# sum_capital_paid_acct_0_12m       11.04
# sum_capital_paid_acct_12_24m      11.04
# sum_paid_inv_0_12m                11.04
# time_hours                        11.04
# dtype: float64

# %% [markdown]
# #### The target variable 'default' has around 10% values as missing, so while imputing the remaining missing values, we are leaving the target variable as the data is highly imbalanced and simply imputing the missing values with Mode won't do justice to the target variable, infact it will increase the imbalance even more.
# #### So first we will impute the remaining missing values in the independent variables and then impute the missing values in the target variable 'default' using 'Mode' value and then resample the data using "SMOTE" which will get rid of the high imbalance in the data.

# %% [markdown]
# * For this we will be imputing the missing values in the independent variables with median value as there are outliers present in the data.

# %%
credit1.isnull().sum()
# Out:
# default                            10001
# acct_amt_added_12_24m                  1
# acct_days_in_dc_12_24m             11837
# acct_days_in_rem_12_24m            11837
# acct_days_in_term_12_24m           11837
# age                                    1
# avg_payment_span_0_12m             23837
# merchant_category                      0
# merchant_group                         0
# has_paid                           11035
# max_paid_inv_0_12m                 11035
# max_paid_inv_0_24m                 11035
# num_active_inv                     11035
# num_arch_dc_0_12m                  11035
# num_arch_dc_12_24m                 11035
# num_arch_ok_0_12m                  11035
# num_arch_ok_12_24m                 11035
# num_arch_rem_0_12m                 11035
# status_max_archived_0_6_months     11035
# status_max_archived_0_12_months    11035
# status_max_archived_0_24_months    11035
# recovery_debt                      11035
# sum_capital_paid_acct_0_12m        11035
# sum_capital_paid_acct_12_24m       11035
# sum_paid_inv_0_12m                 11035
# time_hours                         11035
# dtype: int64

# %% [markdown]
# * Imputing the remaining missing values

# %%
credit1.columns[1:]
# Out:
# Index(['acct_amt_added_12_24m', 'acct_days_in_dc_12_24m',
#        'acct_days_in_rem_12_24m', 'acct_days_in_term_12_24m', 'age',
#        'avg_payment_span_0_12m', 'merchant_category', 'merchant_group',
#        'has_paid', 'max_paid_inv_0_12m', 'max_paid_inv_0_24m',
#        'num_active_inv', 'num_arch_dc_0_12m', 'num_arch_dc_12_24m',
#        'num_arch_ok_0_12m', 'num_arch_ok_12_24m', 'num_arch_rem_0_12m',
#        'status_max_archived_0_6_months', 'status_max_archived_0_12_months',
#        'status_max_archived_0_24_months', 'recovery_debt',
#        'sum_capital_paid_acct_0_12m', 'sum_capital_paid_acct_12_24m',
#        'sum_paid_inv_0_12m', 'time_hours'],
#       dtype='object')

# %%
credit_num=credit1.drop(['merchant_category','merchant_group'], axis=1)

# %%
credit_num.columns
# Out:
# Index(['default', 'acct_amt_added_12_24m', 'acct_days_in_dc_12_24m',
#        'acct_days_in_rem_12_24m', 'acct_days_in_term_12_24m', 'age',
#        'avg_payment_span_0_12m', 'has_paid', 'max_paid_inv_0_12m',
#        'max_paid_inv_0_24m', 'num_active_inv', 'num_arch_dc_0_12m',
#        'num_arch_dc_12_24m', 'num_arch_ok_0_12m', 'num_arch_ok_12_24m',
#        'num_arch_rem_0_12m', 'status_max_archived_0_6_months',
#        'status_max_archived_0_12_months', 'status_max_archived_0_24_months',
#        'recovery_debt', 'sum_capital_paid_acct_0_12m',
#        'sum_capital_paid_acct_12_24m', 'sum_paid_inv_0_12m', 'time_hours'],
#       dtype='object')

# %%
for c in credit_num.columns[1:]:
    median_value = credit_num[c].median()  # Calculate the median for the column
    credit1[c].fillna(median_value, inplace=True)  # Impute missing values with the median

# %%
credit1.isnull().sum()
# Out:
# default                            10001
# acct_amt_added_12_24m                  0
# acct_days_in_dc_12_24m                 0
# acct_days_in_rem_12_24m                0
# acct_days_in_term_12_24m               0
# age                                    0
# avg_payment_span_0_12m                 0
# merchant_category                      0
# merchant_group                         0
# has_paid                               0
# max_paid_inv_0_12m                     0
# max_paid_inv_0_24m                     0
# num_active_inv                         0
# num_arch_dc_0_12m                      0
# num_arch_dc_12_24m                     0
# num_arch_ok_0_12m                      0
# num_arch_ok_12_24m                     0
# num_arch_rem_0_12m                     0
# status_max_archived_0_6_months         0
# status_max_archived_0_12_months        0
# status_max_archived_0_24_months        0
# recovery_debt                          0
# sum_capital_paid_acct_0_12m            0
# sum_capital_paid_acct_12_24m           0
# sum_paid_inv_0_12m                     0
# time_hours                             0
# dtype: int64

# %% [markdown]
# #### As we can see, missing values from all the variables except the target variable has been treated.

# %% [markdown]
# #### Now imputing the missing values in the target variable using the mode value i.e. 0 in this case.
# #### We will resample the data using "SMOTE" later on.

# %%
credit1.shape
# Out:
# (99977, 26)

# %%
credit1.describe().T
# Out:
#                                    count     mean      std   min     25%  \
# default                         89976.00     0.01     0.12  0.00    0.00
# acct_amt_added_12_24m           99977.00 12255.03 35481.33  0.00    0.00
# acct_days_in_dc_12_24m          99977.00     0.20     5.45  0.00    0.00
# acct_days_in_rem_12_24m         99977.00     4.45    21.53  0.00    0.00
# acct_days_in_term_12_24m        99977.00     0.25     2.75  0.00    0.00
# age                             99977.00    36.02    13.00 18.00   25.00
# avg_payment_span_0_12m          99977.00    17.24    11.20  0.00   12.20
# has_paid                        99977.00     0.88     0.32  0.00    1.00
# max_paid_inv_0_12m              99977.00  9010.41 12934.60  0.00 2990.00
# max_paid_inv_0_24m              99977.00 11011.37 14601.30  0.00 4250.00
# num_active_inv                  99977.00     0.56     1.53  0.00    0.00
# num_arch_dc_0_12m               99977.00     0.06     0.36  0.00    0.00
# num_arch_dc_12_24m              99977.00     0.05     0.34  0.00    0.00
# num_arch_ok_0_12m               99977.00     7.26    15.86  0.00    1.00
# num_arch_ok_12_24m              99977.00     6.31    15.23  0.00    0.00
# num_arch_rem_0_12m              99977.00     0.43     1.33  0.00    0.00
# status_max_archived_0_6_months  99977.00     0.84     0.68  0.00    0.00
# status_max_archived_0_12_months 99977.00     1.07     0.73  0.00    1.00
# status_max_archived_0_24_months 99977.00     1.22     0.78  0.00    1.00
# recovery_debt                   99977.00     3.20   109.62  0.00    0.00
# sum_capital_paid_acct_0_12m     99977.00  9661.66 25347.58  0.00    0.00
# sum_capital_paid_acct_12_24m    99977.00  5884.88 18268.80  0.00    0.00
# sum_paid_inv_0_12m              99977.00 38389.69 89539.45  0.00 4870.00
# time_hours                      99977.00    15.39     4.75  0.00   12.16
#
#                                      50%      75%        max
# default                             0.00     0.00       1.00
# acct_amt_added_12_24m               0.00  4937.00 1128775.00
# acct_days_in_dc_12_24m              0.00     0.00     365.00
# acct_days_in_rem_12_24m             0.00     0.00     365.00
# acct_days_in_term_12_24m            0.00     0.00      97.00
# age                                34.00    45.00     100.00
# avg_payment_span_0_12m             14.91    18.59     260.00
# has_paid                            1.00     1.00       1.00
# max_paid_inv_0_12m               6170.00 10570.00  279000.00
# max_paid_inv_0_24m               7720.00 12785.00  538500.00
# num_active_inv                      0.00     1.00      47.00
# num_arch_dc_0_12m                   0.00     0.00      17.00
# num_arch_dc_12_24m                  0.00     0.00      13.00
# num_arch_ok_0_12m                   3.00     7.00     261.00
# num_arch_ok_12_24m                  2.00     6.00     313.00
# num_arch_rem_0_12m                  0.00     0.00      42.00
# status_max_archived_0_6_months      1.00     1.00       3.00
# status_max_archived_0_12_months     1.00     1.00       5.00
# status_max_archived_0_24_months     1.00     2.00       5.00
# recovery_debt                       0.00     0.00   16411.00
# sum_capital_paid_acct_0_12m         0.00  5670.00  571475.00
# sum_capital_paid_acct_12_24m        0.00     0.00  341859.00
# sum_paid_inv_0_12m              17057.50 40393.00 2962870.00
# time_hours                         15.81    19.17      24.00

# %%
credit1['default']
# Out:
# 0       0.00
# 1       0.00
# 2       0.00
# 3       0.00
# 4       0.00
#         ...
# 99972    nan
# 99973    nan
# 99974    nan
# 99975    nan
# 99976    nan
# Name: default, Length: 99977, dtype: float64

# %%
credit1['default'].fillna(0,inplace = True)

# %%
credit1.isnull().sum()
# Out:
# default                            0
# acct_amt_added_12_24m              0
# acct_days_in_dc_12_24m             0
# acct_days_in_rem_12_24m            0
# acct_days_in_term_12_24m           0
# age                                0
# avg_payment_span_0_12m             0
# merchant_category                  0
# merchant_group                     0
# has_paid                           0
# max_paid_inv_0_12m                 0
# max_paid_inv_0_24m                 0
# num_active_inv                     0
# num_arch_dc_0_12m                  0
# num_arch_dc_12_24m                 0
# num_arch_ok_0_12m                  0
# num_arch_ok_12_24m                 0
# num_arch_rem_0_12m                 0
# status_max_archived_0_6_months     0
# status_max_archived_0_12_months    0
# status_max_archived_0_24_months    0
# recovery_debt                      0
# sum_capital_paid_acct_0_12m        0
# sum_capital_paid_acct_12_24m       0
# sum_paid_inv_0_12m                 0
# time_hours                         0
# dtype: int64

# %% [markdown]
# #### As we can see, missing values from all the variables including the target variable has been treated.

# %% [markdown]
# ----

# %% [markdown]
# ## e) Outlier treatment

# %% [markdown]
# #### Checking the outliers per column using boxplot

# %%
plt.figure(figsize=(26,28))
p=1
for i in credit1.drop(['default','merchant_category','merchant_group'],axis=1):
    plt.subplot(8,3,p)
    p=p+1
    sns.boxplot(data=credit1, x=credit1[i])
    plt.title('boxplot of {}'.format(i), fontsize=20)
    plt.xticks(fontsize=14)
    plt.xlabel(i, fontsize=16)
    plt.tight_layout()

# %% [markdown]
# * All the variables have outliers except 'time_hours'.
# * Some variables have one or two outliers while some have a large number of outliers.
# * Thus, we are going to use Inter-quartile-range (IQR) method for treating the outliers.

# %%
for i in credit1.drop(['default','merchant_category','merchant_group'],axis=1):
    q1=credit1[i].quantile(0.25)
    q3=credit1[i].quantile(0.75)
    iqr=q3-q1
    ul = q3 + (1.5 * iqr)
    ll = q1 - (1.5 * iqr)
    credit1[i]=np.where(credit1[i]>ul,ul,credit1[i])
    credit1[i]=np.where(credit1[i]<ll,ll,credit1[i])

# %% [markdown]
# #### Checking the boxplots again

# %%
plt.figure(figsize=(26,28))
p=1
for i in credit1.drop(['default','merchant_category','merchant_group'],axis=1):
    plt.subplot(8,3,p)
    p=p+1
    sns.boxplot(data=credit1, x=credit1[i])
    plt.title('boxplot of {}'.format(i), fontsize=20)
    plt.xticks(fontsize=14)
    plt.xlabel(i, fontsize=16)
    plt.tight_layout()

# %% [markdown]
# #### As we can see outliers, all the outliers have been treated, but some of the variables have only zeroes left. Therefore dropping such variables.

# %%
credit1.describe().T
# Out:
#                                    count     mean      std   min     25%  \
# default                         99977.00     0.01     0.11  0.00    0.00
# acct_amt_added_12_24m           99977.00  2976.08  5052.51  0.00    0.00
# acct_days_in_dc_12_24m          99977.00     0.00     0.00  0.00    0.00
# acct_days_in_rem_12_24m         99977.00     0.00     0.00  0.00    0.00
# acct_days_in_term_12_24m        99977.00     0.00     0.00  0.00    0.00
# age                             99977.00    35.99    12.93 18.00   25.00
# avg_payment_span_0_12m          99977.00    15.80     6.33  2.61   12.20
# has_paid                        99977.00     1.00     0.00  1.00    1.00
# max_paid_inv_0_12m              99977.00  7535.97  6412.96  0.00 2990.00
# max_paid_inv_0_24m              99977.00  9307.62  7411.15  0.00 4250.00
# num_active_inv                  99977.00     0.42     0.75  0.00    0.00
# num_arch_dc_0_12m               99977.00     0.00     0.00  0.00    0.00
# num_arch_dc_12_24m              99977.00     0.00     0.00  0.00    0.00
# num_arch_ok_0_12m               99977.00     4.66     5.18  0.00    1.00
# num_arch_ok_12_24m              99977.00     3.97     4.93  0.00    0.00
# num_arch_rem_0_12m              99977.00     0.00     0.00  0.00    0.00
# status_max_archived_0_6_months  99977.00     0.83     0.66  0.00    0.00
# status_max_archived_0_12_months 99977.00     1.00     0.00  1.00    1.00
# status_max_archived_0_24_months 99977.00     1.22     0.78  0.00    1.00
# recovery_debt                   99977.00     0.00     0.00  0.00    0.00
# sum_capital_paid_acct_0_12m     99977.00  3401.02  5720.21  0.00    0.00
# sum_capital_paid_acct_12_24m    99977.00     0.00     0.00  0.00    0.00
# sum_paid_inv_0_12m              99977.00 27837.29 29804.50  0.00 4870.00
# time_hours                      99977.00    15.41     4.71  1.64   12.16
#
#                                      50%      75%      max
# default                             0.00     0.00     1.00
# acct_amt_added_12_24m               0.00  4937.00 12342.50
# acct_days_in_dc_12_24m              0.00     0.00     0.00
# acct_days_in_rem_12_24m             0.00     0.00     0.00
# acct_days_in_term_12_24m            0.00     0.00     0.00
# age                                34.00    45.00    75.00
# avg_payment_span_0_12m             14.91    18.59    28.19
# has_paid                            1.00     1.00     1.00
# max_paid_inv_0_12m               6170.00 10570.00 21940.00
# max_paid_inv_0_24m               7720.00 12785.00 25587.50
# num_active_inv                      0.00     1.00     2.50
# num_arch_dc_0_12m                   0.00     0.00     0.00
# num_arch_dc_12_24m                  0.00     0.00     0.00
# num_arch_ok_0_12m                   3.00     7.00    16.00
# num_arch_ok_12_24m                  2.00     6.00    15.00
# num_arch_rem_0_12m                  0.00     0.00     0.00
# status_max_archived_0_6_months      1.00     1.00     2.50
# status_max_archived_0_12_months     1.00     1.00     1.00
# status_max_archived_0_24_months     1.00     2.00     3.50
# recovery_debt                       0.00     0.00     0.00
# sum_capital_paid_acct_0_12m         0.00  5670.00 14175.00
# sum_capital_paid_acct_12_24m        0.00     0.00     0.00
# sum_paid_inv_0_12m              17057.50 40393.00 93677.50
# time_hours                         15.81    19.17    24.00

# %%
credit1.drop(['acct_days_in_dc_12_24m','acct_days_in_rem_12_24m','acct_days_in_term_12_24m',
              'num_arch_dc_0_12m','num_arch_dc_12_24m','num_arch_rem_0_12m',
              'recovery_debt','sum_capital_paid_acct_12_24m','has_paid',
              'status_max_archived_0_12_months'],axis=1, inplace = True)

# %%
credit1.describe().T
# Out:
#                                    count     mean      std   min     25%  \
# default                         99977.00     0.01     0.11  0.00    0.00
# acct_amt_added_12_24m           99977.00  2976.08  5052.51  0.00    0.00
# age                             99977.00    35.99    12.93 18.00   25.00
# avg_payment_span_0_12m          99977.00    15.80     6.33  2.61   12.20
# max_paid_inv_0_12m              99977.00  7535.97  6412.96  0.00 2990.00
# max_paid_inv_0_24m              99977.00  9307.62  7411.15  0.00 4250.00
# num_active_inv                  99977.00     0.42     0.75  0.00    0.00
# num_arch_ok_0_12m               99977.00     4.66     5.18  0.00    1.00
# num_arch_ok_12_24m              99977.00     3.97     4.93  0.00    0.00
# status_max_archived_0_6_months  99977.00     0.83     0.66  0.00    0.00
# status_max_archived_0_24_months 99977.00     1.22     0.78  0.00    1.00
# sum_capital_paid_acct_0_12m     99977.00  3401.02  5720.21  0.00    0.00
# sum_paid_inv_0_12m              99977.00 27837.29 29804.50  0.00 4870.00
# time_hours                      99977.00    15.41     4.71  1.64   12.16
#
#                                      50%      75%      max
# default                             0.00     0.00     1.00
# acct_amt_added_12_24m               0.00  4937.00 12342.50
# age                                34.00    45.00    75.00
# avg_payment_span_0_12m             14.91    18.59    28.19
# max_paid_inv_0_12m               6170.00 10570.00 21940.00
# max_paid_inv_0_24m               7720.00 12785.00 25587.50
# num_active_inv                      0.00     1.00     2.50
# num_arch_ok_0_12m                   3.00     7.00    16.00
# num_arch_ok_12_24m                  2.00     6.00    15.00
# status_max_archived_0_6_months      1.00     1.00     2.50
# status_max_archived_0_24_months     1.00     2.00     3.50
# sum_capital_paid_acct_0_12m         0.00  5670.00 14175.00
# sum_paid_inv_0_12m              17057.50 40393.00 93677.50
# time_hours                         15.81    19.17    24.00

# %% [markdown]
# #### Finally we are left with only 14 variables.

# %% [markdown]
# #### Checking the boxplots again

# %%
plt.figure(figsize=(26,28))
p=1
for i in credit1.drop(['default','merchant_category','merchant_group'],axis=1):
    plt.subplot(8,3,p)
    p=p+1
    sns.boxplot(data=credit1, x=credit1[i])
    plt.title('boxplot of {}'.format(i), fontsize=20)
    plt.xticks(fontsize=14)
    plt.xlabel(i, fontsize=16)
    plt.tight_layout()

# %% [markdown]
# ---

# %% [markdown]
# ## f) Variable transformation

# %% [markdown]
# #### Segregate the predictors and response

# %%
predictors = credit1.drop(['default','merchant_category','merchant_group'],axis=1)
response = credit1['default']

# %% [markdown]
# * Scaling the predictors using StandardScaler (response binary in nature, doesn't need scaling)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_predictors = pd.DataFrame(scaler.fit_transform(predictors), columns = predictors.columns)

# %%
credit1_scaled = pd.concat([scaled_predictors, response], axis = 1)

# %%
credit1_scaled.columns
# Out:
# Index(['acct_amt_added_12_24m', 'age', 'avg_payment_span_0_12m',
#        'max_paid_inv_0_12m', 'max_paid_inv_0_24m', 'num_active_inv',
#        'num_arch_ok_0_12m', 'num_arch_ok_12_24m',
#        'status_max_archived_0_6_months', 'status_max_archived_0_24_months',
#        'sum_capital_paid_acct_0_12m', 'sum_paid_inv_0_12m', 'time_hours',
#        'default'],
#       dtype='object')

# %%
credit1_scaled.head()
# Out:
#    acct_amt_added_12_24m   age  avg_payment_span_0_12m  max_paid_inv_0_12m  \
# 0                  -0.59 -1.24                   -0.49                2.25
# 1                  -0.59  1.08                    1.59                0.97
# 2                  -0.59 -1.08                    0.66                2.25
# 3                  -0.59  0.00                   -1.76                2.25
# 4                  -0.59 -0.85                   -0.44               -0.07
#
#    max_paid_inv_0_24m  num_active_inv  num_arch_ok_0_12m  num_arch_ok_12_24m  \
# 0                2.20            2.12               1.61                2.04
# 1                0.60           -0.56               0.84                2.24
# 2                2.20            0.78               1.22               -0.80
# 3                2.20            0.78               2.19                2.24
# 4               -0.30           -0.56              -0.71               -0.80
#
#    status_max_archived_0_6_months  status_max_archived_0_24_months  \
# 0                            0.25                            -0.28
# 1                            0.25                             1.00
# 2                            0.25                             1.00
# 3                            0.25                            -0.28
# 4                            0.25                            -0.28
#
#    sum_capital_paid_acct_0_12m  sum_paid_inv_0_12m  time_hours  default
# 0                        -0.59                2.21       -1.22     0.00
# 1                        -0.59                0.71       -0.47     0.00
# 2                        -0.59                2.21       -0.82     0.00
# 3                        -0.59                2.21        0.07     0.00
# 4                        -0.59               -0.70       -0.58     0.00

# %%
credit1_scaled.describe().T
# Out:
#                                    count  mean  std   min   25%   50%  75%  \
# acct_amt_added_12_24m           99977.00  0.00 1.00 -0.59 -0.59 -0.59 0.39
# age                             99977.00 -0.00 1.00 -1.39 -0.85 -0.15 0.70
# avg_payment_span_0_12m          99977.00  0.00 1.00 -2.09 -0.57 -0.14 0.44
# max_paid_inv_0_12m              99977.00  0.00 1.00 -1.18 -0.71 -0.21 0.47
# max_paid_inv_0_24m              99977.00  0.00 1.00 -1.26 -0.68 -0.21 0.47
# num_active_inv                  99977.00 -0.00 1.00 -0.56 -0.56 -0.56 0.78
# num_arch_ok_0_12m               99977.00 -0.00 1.00 -0.90 -0.71 -0.32 0.45
# num_arch_ok_12_24m              99977.00 -0.00 1.00 -0.80 -0.80 -0.40 0.41
# status_max_archived_0_6_months  99977.00  0.00 1.00 -1.27 -1.27  0.25 0.25
# status_max_archived_0_24_months 99977.00 -0.00 1.00 -1.57 -0.28 -0.28 1.00
# sum_capital_paid_acct_0_12m     99977.00 -0.00 1.00 -0.59 -0.59 -0.59 0.40
# sum_paid_inv_0_12m              99977.00  0.00 1.00 -0.93 -0.77 -0.36 0.42
# time_hours                      99977.00 -0.00 1.00 -2.93 -0.69  0.09 0.80
# default                         99977.00  0.01 0.11  0.00  0.00  0.00 0.00
#
#                                  max
# acct_amt_added_12_24m           1.85
# age                             3.02
# avg_payment_span_0_12m          1.96
# max_paid_inv_0_12m              2.25
# max_paid_inv_0_24m              2.20
# num_active_inv                  2.79
# num_arch_ok_0_12m               2.19
# num_arch_ok_12_24m              2.24
# status_max_archived_0_6_months  2.54
# status_max_archived_0_24_months 2.93
# sum_capital_paid_acct_0_12m     1.88
# sum_paid_inv_0_12m              2.21
# time_hours                      1.83
# default                         1.00

# %% [markdown]
# ----

# %% [markdown]
# ----

# %% [markdown]
# # 4) Business insights from EDA

# %% [markdown]
# ## a) Is the data unbalanced? If so, what can be done? Please explain in the context of the business

# %% [markdown]
# #### Checking the target variable 'default'

# %%
credit['default'].value_counts()
# Out:
# 0.00    88688
# 1.00     1288
# Name: default, dtype: int64

# %% [markdown]
# #### Checking the proportion of default

# %%
credit['default'].value_counts(normalize = True)
# Out:
# 0.00   0.99
# 1.00   0.01
# Name: default, dtype: float64

# %%
credit1['default'].value_counts()
# Out:
# 0.00    98689
# 1.00     1288
# Name: default, dtype: int64

# %%
credit1['default'].value_counts(normalize = True)
# Out:
# 0.00   0.99
# 1.00   0.01
# Name: default, dtype: float64

# %% [markdown]
# * Dataset is highly unbalanced as 'defaulters' constitute only 1% of the dataset.
# * Hence we can balance it using 'SMOTE' in order to improve the models that will be build later on.

# %% [markdown]
# ----

# %% [markdown]
# ### b) Any business insights using clustering

# %% [markdown]
# We know that in presence of outliers, mean is the parameter that is affected the most. In case of K means clustering, to calculate the centroids mean is calculated again and again till we get the final centroid. So of course, K means clustering will be very sensitive to outliers.
# Since our aim is to perform clustering, we are only concerned about outliers present in those variables which are required for clustering,
# hence dropping the redundant variables first:

# %%
credit1_scaled.describe().T
# Out:
#                                    count  mean  std   min   25%   50%  75%  \
# acct_amt_added_12_24m           99977.00  0.00 1.00 -0.59 -0.59 -0.59 0.39
# age                             99977.00 -0.00 1.00 -1.39 -0.85 -0.15 0.70
# avg_payment_span_0_12m          99977.00  0.00 1.00 -2.09 -0.57 -0.14 0.44
# max_paid_inv_0_12m              99977.00  0.00 1.00 -1.18 -0.71 -0.21 0.47
# max_paid_inv_0_24m              99977.00  0.00 1.00 -1.26 -0.68 -0.21 0.47
# num_active_inv                  99977.00 -0.00 1.00 -0.56 -0.56 -0.56 0.78
# num_arch_ok_0_12m               99977.00 -0.00 1.00 -0.90 -0.71 -0.32 0.45
# num_arch_ok_12_24m              99977.00 -0.00 1.00 -0.80 -0.80 -0.40 0.41
# status_max_archived_0_6_months  99977.00  0.00 1.00 -1.27 -1.27  0.25 0.25
# status_max_archived_0_24_months 99977.00 -0.00 1.00 -1.57 -0.28 -0.28 1.00
# sum_capital_paid_acct_0_12m     99977.00 -0.00 1.00 -0.59 -0.59 -0.59 0.40
# sum_paid_inv_0_12m              99977.00  0.00 1.00 -0.93 -0.77 -0.36 0.42
# time_hours                      99977.00 -0.00 1.00 -2.93 -0.69  0.09 0.80
# default                         99977.00  0.01 0.11  0.00  0.00  0.00 0.00
#
#                                  max
# acct_amt_added_12_24m           1.85
# age                             3.02
# avg_payment_span_0_12m          1.96
# max_paid_inv_0_12m              2.25
# max_paid_inv_0_24m              2.20
# num_active_inv                  2.79
# num_arch_ok_0_12m               2.19
# num_arch_ok_12_24m              2.24
# status_max_archived_0_6_months  2.54
# status_max_archived_0_24_months 2.93
# sum_capital_paid_acct_0_12m     1.88
# sum_paid_inv_0_12m              2.21
# time_hours                      1.83
# default                         1.00

# %% [markdown]
# #### Using K-Means clustering and since it comes under unsupervised learning we will do clustering containing all the varibles except the target variable.

# %% [markdown]
# #### Making an Elbow plot (up to n=10) and identifying optimum number of clusters for k-means algorithm.

# %%
from sklearn.cluster import KMeans
wss=[]
for k in range(1,11):
    kmeans = KMeans(n_clusters=k, random_state = 123)
    kmeans.fit(predictors)
    wss.append(kmeans.inertia_)
plt.figure(figsize=(10,7))
plt.xticks(np.arange(1,11))
plt.plot(range(1,11),wss,marker='o')
plt.title('Elbow plot for k-means clustering', fontsize=15)
plt.xlabel('Number of Clusters', fontsize=12)
plt.ylabel('Inertia (or) Within Cluster sum of squares(wss)', fontsize=12)
plt.show()

# %% [markdown]
# #### As we can see in the Elbow plot, optimum number of clusters for the given k-means algorithm is 3. As after 3 there is no sharp decline in within sums of squares value.

# %% [markdown]
# * Optimum number of clusters using the elbow plot was found out to be 3. So taking number of clusters as 3 and clustering the data we get the following table:

# %%
k_means=KMeans(n_clusters=3, random_state = 123)
k_means.fit(predictors)
clusters = k_means.labels_
credit1.insert(0,'Clusters', clusters)
credit1.head()
# Out:
#    Clusters  default  acct_amt_added_12_24m   age  avg_payment_span_0_12m  \
# 0         1     0.00                   0.00 20.00                   12.69
# 1         2     0.00                   0.00 50.00                   25.83
# 2         1     0.00                   0.00 22.00                   20.00
# 3         1     0.00                   0.00 36.00                    4.69
# 4         0     0.00                   0.00 25.00                   13.00
#
#                             merchant_category   merchant_group  \
# 0                         Dietary supplements  Health & Beauty
# 1                           Books & Magazines    Entertainment
# 2                   Diversified entertainment    Entertainment
# 3                   Diversified entertainment    Entertainment
# 4  Electronic equipment & Related accessories      Electronics
#
#    max_paid_inv_0_12m  max_paid_inv_0_24m  num_active_inv  num_arch_ok_0_12m  \
# 0            21940.00            25587.50            2.00              13.00
# 1            13749.00            13749.00            0.00               9.00
# 2            21940.00            25587.50            1.00              11.00
# 3            21940.00            25587.50            1.00              16.00
# 4             7100.00             7100.00            0.00               1.00
#
#    num_arch_ok_12_24m  status_max_archived_0_6_months  \
# 0               14.00                            1.00
# 1               15.00                            1.00
# 2                0.00                            1.00
# 3               15.00                            1.00
# 4                0.00                            1.00
#
#    status_max_archived_0_24_months  sum_capital_paid_acct_0_12m  \
# 0                             1.00                         0.00
# 1                             2.00                         0.00
# 2                             2.00                         0.00
# 3                             1.00                         0.00
# 4                             1.00                         0.00
#
#    sum_paid_inv_0_12m  time_hours
# 0            93677.50        9.65
# 1            49014.00       13.18
# 2            93677.50       11.56
# 3            93677.50       15.75
# 4             7100.00       12.70

# %%
credit1.Clusters.value_counts().sort_index()
# Out:
# 0    62126
# 1    15952
# 2    21899
# Name: Clusters, dtype: int64

# %%
credit1.head()
# Out:
#    Clusters  default  acct_amt_added_12_24m   age  avg_payment_span_0_12m  \
# 0         1     0.00                   0.00 20.00                   12.69
# 1         2     0.00                   0.00 50.00                   25.83
# 2         1     0.00                   0.00 22.00                   20.00
# 3         1     0.00                   0.00 36.00                    4.69
# 4         0     0.00                   0.00 25.00                   13.00
#
#                             merchant_category   merchant_group  \
# 0                         Dietary supplements  Health & Beauty
# 1                           Books & Magazines    Entertainment
# 2                   Diversified entertainment    Entertainment
# 3                   Diversified entertainment    Entertainment
# 4  Electronic equipment & Related accessories      Electronics
#
#    max_paid_inv_0_12m  max_paid_inv_0_24m  num_active_inv  num_arch_ok_0_12m  \
# 0            21940.00            25587.50            2.00              13.00
# 1            13749.00            13749.00            0.00               9.00
# 2            21940.00            25587.50            1.00              11.00
# 3            21940.00            25587.50            1.00              16.00
# 4             7100.00             7100.00            0.00               1.00
#
#    num_arch_ok_12_24m  status_max_archived_0_6_months  \
# 0               14.00                            1.00
# 1               15.00                            1.00
# 2                0.00                            1.00
# 3               15.00                            1.00
# 4                0.00                            1.00
#
#    status_max_archived_0_24_months  sum_capital_paid_acct_0_12m  \
# 0                             1.00                         0.00
# 1                             2.00                         0.00
# 2                             2.00                         0.00
# 3                             1.00                         0.00
# 4                             1.00                         0.00
#
#    sum_paid_inv_0_12m  time_hours
# 0            93677.50        9.65
# 1            49014.00       13.18
# 2            93677.50       11.56
# 3            93677.50       15.75
# 4             7100.00       12.70

# %%
credit1_sub = credit1[['merchant_group','Clusters','age','acct_amt_added_12_24m','avg_payment_span_0_12m']]
credit1_sub.head()
# Out:
#     merchant_group  Clusters   age  acct_amt_added_12_24m  \
# 0  Health & Beauty         1 20.00                   0.00
# 1    Entertainment         2 50.00                   0.00
# 2    Entertainment         1 22.00                   0.00
# 3    Entertainment         1 36.00                   0.00
# 4      Electronics         0 25.00                   0.00
#
#    avg_payment_span_0_12m
# 0                   12.69
# 1                   25.83
# 2                   20.00
# 3                    4.69
# 4                   13.00

# %%
Freq = credit1_sub.groupby('merchant_group').Clusters.value_counts().sort_index()
Freq
# Out:
# merchant_group         Clusters
# Automotive Products    0             665
#                        1              83
#                        2             189
# Children Products      0            3028
#                        1             874
#                        2            1206
# Clothing & Shoes       0            9437
#                        1            2822
#                        2            4469
# Electronics            0            2076
#                        1             360
#                        2             598
# Entertainment          0           26756
#                        1            9784
#                        2           12249
# Erotic Materials       0             523
#                        1              81
#                        2             143
# Food & Beverage        0             242
#                        1              58
#                        2              55
# Health & Beauty        0            4321
#                        1            1178
#                        2            1857
# Home & Garden          0            2451
#                        1             498
#                        2             769
# Intangible products    0             955
#                        1              51
#                        2             116
# Jewelry & Accessories  0             647
#                        1             163
#                        2             248
# Leisure                0           11025
# Name: Clusters, dtype: int64

# %% [markdown]
# #### Grouping the data by Clusters and taking mean to identify trends in acct_amt_added_12_24m, avg_payment_span_0_12m, avg_payment_span_0_12m and age based on merchant_group:

# %%
credit_profile = credit1_sub.groupby(['merchant_group','Clusters']).mean()
credit_profile.insert(0,'Frequency', Freq)
credit_profile
# Out:
#                                 Frequency   age  acct_amt_added_12_24m  \
# merchant_group        Clusters
# Automotive Products   0               665 37.24                1886.10
#                       1                83 34.18                3589.90
#                       2               189 35.02                3145.09
# Children Products     0              3028 35.19                2434.65
#                       1               874 32.61                6395.78
#                       2              1206 32.57                4974.68
# Clothing & Shoes      0              9437 30.36                2512.09
#                       1              2822 30.71                6068.79
#                       2              4469 29.57                4971.30
# Electronics           0              2076 37.31                2505.59
#                       1               360 33.64                4235.69
#                       2               598 34.98                4384.27
# Entertainment         0             26756 37.64                1834.52
#                       1              9784 38.00                3861.22
#                       2             12249 37.32                3143.55
# Erotic Materials      0               523 34.70                2121.65
#                       1                81 33.10                4786.58
#                       2               143 32.36                4411.26
# Food & Beverage       0               242 39.39                2835.89
#                       1                58 38.53                4039.95
#                       2                55 32.75                5677.34
# Health & Beauty       0              4321 33.95                2321.18
#                       1              1178 31.57                5030.45
#                       2              1857 31.07                4182.38
# Home & Garden         0              2451 39.82                2376.13
#                       1               498 34.22                5291.80
#                       2               769 34.76                4726.10
# Intangible products   0               955 45.93                2270.39
#                       1                51 35.73                6053.11
#                       2               116 37.26                4439.80
# Jewelry & Accessories 0               647 34.79                2968.66
#                       1               163 32.06                6286.31
#                       2               248 32.86                5066.56
# Leisure               0             11025 39.04                2929.29
#
#                                 avg_payment_span_0_12m
# merchant_group        Clusters
# Automotive Products   0                          15.16
#                       1                          15.59
#                       2                          16.17
# Children Products     0                          15.97
#                       1                          17.99
#                       2                          18.27
# Clothing & Shoes      0                          16.33
#                       1                          18.24
#                       2                          18.79
# Electronics           0                          15.29
#                       1                          15.48
#                       2                          16.59
# Entertainment         0                          14.94
#                       1                          14.71
#                       2                          15.27
# Erotic Materials      0                          15.85
#                       1                          15.68
#                       2                          17.94
# Food & Beverage       0                          14.91
#                       1                          16.98
#                       2                          17.73
# Health & Beauty       0                          15.78
#                       1                          16.72
#                       2                          17.08
# Home & Garden         0                          16.13
#                       1                          18.20
#                       2                          18.30
# Intangible products   0                          15.98
#                       1                          18.34
#                       2                          18.49
# Jewelry & Accessories 0                          15.48
#                       1                          16.99
#                       2                          18.11
# Leisure               0                          16.00

# %% [markdown]
# -----

# %% [markdown]
# -----

# %% [markdown]
# -----

# %% [markdown]
# # NOTES II : MODEL BUILDING AND TUNING

# %% [markdown]
# ### we must first balance the target variable 'default' using SMOTE.

# %% [markdown]
# #### Splitting the data into train and test sets

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(predictors, response,
                                        test_size = 0.30, random_state = 1, stratify = response)

# %%
response.value_counts(normalize=True)
# Out:
# 0.00   0.99
# 1.00   0.01
# Name: default, dtype: float64

# %%
from imblearn.over_sampling import SMOTE 
smote = SMOTE(random_state= 1, sampling_strategy=0.67)
X_res, y_res = smote.fit_resample(X_train, y_train)

# %%
print('Resampled class proportion:')
print('---------------------------')
print(y_res.value_counts(normalize = True),'\n\n')
print('Original class proportion:')
print('--------------------------')
print(response.value_counts(normalize = True))
# Out:
# Resampled class proportion:
# ---------------------------
# 0.00   0.60
# 1.00   0.40
# Name: default, dtype: float64
#
#
# Original class proportion:
# --------------------------
# 0.00   0.99
# 1.00   0.01
# Name: default, dtype: float64

# %% [markdown]
# * As we can see after resampling the data, we got our new resampled predictors and response namely "X_res" and "y_res" and these will be our new training data which will be used for our model building later on.

# %% [markdown]
# # Building Models

# %% [markdown]
# ### Getting the test and train predictors and responses for model building
# * We have applied SMOTE only to the training data and not the testing data as we want to preserve the original data for testing our model.
# * Taking a copy of resampled training data and the original test data for model building.

# %%
X_train1 = X_res.copy()
X_test1 = X_test.copy()

# %% [markdown]
# ## 1.) Logistic Regression Model

# %%
X_train2 = sm.add_constant(X_train1)  # Adding a constant term (intercept)

# %%
X_test2 = sm.add_constant(X_test1)

# %%
logit_model = sm.Logit(y_res, X_train2)  
result_lgr = logit_model.fit()

print(result_lgr.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.504823
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                default   No. Observations:               115365
# Model:                          Logit   Df Residuals:                   115351
# Method:                           MLE   Df Model:                           13
# Date:                Sun, 05 May 2024   Pseudo R-squ.:                  0.2504
# Time:                        12:07:50   Log-Likelihood:                -58239.
# converged:                       True   LL-Null:                       -77698.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                               0.5118      0.039     12.986      0.000       0.435       0.589
# acct_amt_added_12_24m            3.553e-05   1.84e-06     19.271      0.000    3.19e-05    3.91e-05
# age                                -0.0264      0.001    -43.593      0.000      -0.028      -0.025
# avg_payment_span_0_12m              0.0511      0.001     35.545      0.000       0.048       0.054
# max_paid_inv_0_12m              -6.322e-05   3.59e-06    -17.608      0.000   -7.03e-05   -5.62e-05
# max_paid_inv_0_24m              -6.503e-05   2.74e-06    -23.741      0.000   -7.04e-05   -5.97e-05
# num_active_inv                      0.6510      0.012     54.274      0.000       0.628       0.675
# num_arch_ok_0_12m                  -0.2497      0.005    -50.014      0.000      -0.259      -0.240
# num_arch_ok_12_24m                 -0.2048      0.004    -50.870      0.000      -0.213      -0.197
# status_max_archived_0_6_months     -0.0225      0.014     -1.574      0.115      -0.050       0.006
# status_max_archived_0_24_months     0.2991      0.012     25.321      0.000       0.276       0.322
# sum_capital_paid_acct_0_12m     -4.458e-06   1.72e-06     -2.598      0.009   -7.82e-06    -1.1e-06
# sum_paid_inv_0_12m               2.499e-05   8.93e-07     27.991      0.000    2.32e-05    2.67e-05
# time_hours                         -0.0182      0.002    -11.588      0.000      -0.021      -0.015
# ===================================================================================================

# %% [markdown]
# * Except for the variable 'status_max_archived_0_6_months', which has a p-value greater than 0.05, all other variables have p-values below 0.05. This suggests that these variables are significant for model building.
#
# * For now, we'll leave the variable 'status_max_archived_0_6_months' as is, but we'll revisit it after addressing multicollinearity. If it remains insignificant for model building, we'll reconsider its inclusion.
#
# * It's important to note that multicollinearity can impact the interpretation of coefficient estimates, even if individual variables are significant. High multicollinearity can lead to unstable coefficient estimates, making it challenging to correctly interpret the predictors' effects. Therefore, it's crucial to address multicollinearity before proceeding further.

# %% [markdown]
# ### Inspecting possible correlations between independent variables to get rid of Multicollinearity.

# %%
plt.figure(figsize = (28,23))
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
cor_matrix = X_train1.corr()
sns.heatmap(cor_matrix, cmap = 'coolwarm', vmin = -1, vmax= 1)
plt.show()

# %% [markdown]
# #### The presence of red squares, particularly along the diagonal line, indicates high correlation among certain features. To address this issue, we'll utilize the Variance Inflation Factor (VIF) method to identify and eliminate highly correlated columns.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif

# %%
i= pd.Series([vif(X_train2.values, j) for j in range(X_train2.shape[1])],index=X_train2.columns)
i.sort_values(ascending =False, inplace = True)
print('VIF Values for the variables:')
print('-----------------------------')
print(i)
# Out:
# VIF Values for the variables:
# -----------------------------
# const                             30.17
# sum_paid_inv_0_12m                 7.93
# max_paid_inv_0_12m                 7.00
# num_arch_ok_0_12m                  5.95
# max_paid_inv_0_24m                 5.44
# num_arch_ok_12_24m                 2.90
# status_max_archived_0_24_months    2.36
# sum_capital_paid_acct_0_12m        1.92
# status_max_archived_0_6_months     1.90
# acct_amt_added_12_24m              1.85
# avg_payment_span_0_12m             1.71
# num_active_inv                     1.30
# age                                1.03
# time_hours                         1.00
# dtype: float64

# %%
pseudo_r_squared = np.round(result_lgr.prsquared, 3)
print("Pseudo R-squared with all the variables present:", pseudo_r_squared)
# Out:
# Pseudo R-squared with all the variables present: 0.25

# %% [markdown]
# #### Based on the VIF values indicating high multicollinearity, particularly among the features 'sum_paid_inv_0_12m', 'max_paid_inv_0_12m', 'num_arch_ok_0_12m', and 'max_paid_inv_0_24m', correlated with one or more independent features, we need to address this issue.
# To mitigate multicollinearity, we'll need to drop one or more of the correlated features. The feature to drop will be chosen based on its minimal impact on the pseudo R-squared of the logistic regression model.
#
#
# ## Let's drop multicollinear features one at a time and observe the effect on the logistic regression model:

# %%
X_train3 = X_train2.drop(["sum_paid_inv_0_12m"], axis=1)
logit_model2 = sm.Logit(y_res, X_train3)  
result_lgr2 = logit_model2.fit()
pseudo_r_squared = np.round(result_lgr2.prsquared, 3)
print("Pseudo R-squared after dropping 'sum_paid_inv_0_12m':", pseudo_r_squared)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.508273
#          Iterations 7
# Pseudo R-squared after dropping 'sum_paid_inv_0_12m': 0.245

# %% [markdown]
# #### On dropping 'sum_paid_inv_0_12m', Pseudo R-squared decreased only by 0.004, thus we can definitely drop 'sum_paid_inv_0_12m'.

# %%
i= pd.Series([vif(X_train3.values, j) for j in range(X_train3.shape[1])],index=X_train3.columns)
i.sort_values(ascending =False, inplace = True)
print('VIF Values for the variables:')
print('-----------------------------')
print(i)
# Out:
# VIF Values for the variables:
# -----------------------------
# const                             29.08
# max_paid_inv_0_12m                 5.58
# max_paid_inv_0_24m                 5.43
# num_arch_ok_0_12m                  3.52
# num_arch_ok_12_24m                 2.88
# status_max_archived_0_24_months    2.36
# sum_capital_paid_acct_0_12m        1.91
# status_max_archived_0_6_months     1.90
# acct_amt_added_12_24m              1.85
# avg_payment_span_0_12m             1.62
# num_active_inv                     1.25
# age                                1.03
# time_hours                         1.00
# dtype: float64

# %%
X_train4 = X_train3.drop(["max_paid_inv_0_12m"], axis=1)
logit_model3 = sm.Logit(y_res, X_train4)  
result_lgr3 = logit_model3.fit()
pseudo_r_squared = np.round(result_lgr3.prsquared, 3)
print("Pseudo R-squared after dropping 'max_paid_inv_0_12m':", pseudo_r_squared)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.508422
#          Iterations 7
# Pseudo R-squared after dropping 'max_paid_inv_0_12m': 0.245

# %% [markdown]
# #### On dropping 'max_paid_inv_0_12m', Pseudo R-squared didnot decrese at all, thus we can definitely drop 'max_paid_inv_0_12m'.

# %%
i= pd.Series([vif(X_train4.values, j) for j in range(X_train4.shape[1])],index=X_train4.columns)
i.sort_values(ascending =False, inplace = True)
print('VIF Values for the variables:')
print('-----------------------------')
print(i)
# Out:
# VIF Values for the variables:
# -----------------------------
# const                             29.07
# num_arch_ok_0_12m                  3.35
# num_arch_ok_12_24m                 2.80
# status_max_archived_0_24_months    2.35
# sum_capital_paid_acct_0_12m        1.91
# acct_amt_added_12_24m              1.84
# status_max_archived_0_6_months     1.84
# max_paid_inv_0_24m                 1.69
# avg_payment_span_0_12m             1.61
# num_active_inv                     1.25
# age                                1.03
# time_hours                         1.00
# dtype: float64

# %% [markdown]
# ### VIF values below 5, and especially close to or below 3, indicate that multicollinearity in the data has been effectively addressed. This suggests that there is little to almost no multicollinearity remaining in our dataset.

# %%
y_res.value_counts()
# Out:
# 0.00    69081
# 1.00    46284
# Name: default, dtype: int64

# %%
y_test.value_counts()
# Out:
# 0.00    29608
# 1.00      386
# Name: default, dtype: int64

# %%
print(y_res.value_counts(normalize=True), y_test.value_counts(normalize=True))
# Out:
# 0.00   0.60
# 1.00   0.40
# Name: default, dtype: float64 0.00   0.99
# 1.00   0.01
# Name: default, dtype: float64

# %% [markdown]
# ----

# %% [markdown]
# #### Building the logit model after treating multicollinearity

# %%
logit_model = sm.Logit(y_res, X_train4)  
result_lgr = logit_model.fit()

print(result_lgr.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.508422
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                default   No. Observations:               115365
# Model:                          Logit   Df Residuals:                   115353
# Method:                           MLE   Df Model:                           11
# Date:                Sun, 05 May 2024   Pseudo R-squ.:                  0.2451
# Time:                        12:07:55   Log-Likelihood:                -58654.
# converged:                       True   LL-Null:                       -77698.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                               0.2814      0.038      7.348      0.000       0.206       0.357
# acct_amt_added_12_24m            3.327e-05   1.83e-06     18.189      0.000    2.97e-05    3.69e-05
# age                                -0.0268      0.001    -44.363      0.000      -0.028      -0.026
# avg_payment_span_0_12m              0.0606      0.001     43.688      0.000       0.058       0.063
# max_paid_inv_0_24m              -7.558e-05   1.64e-06    -46.093      0.000   -7.88e-05   -7.24e-05
# num_active_inv                      0.7078      0.012     59.614      0.000       0.685       0.731
# num_arch_ok_0_12m                  -0.1707      0.004    -44.689      0.000      -0.178      -0.163
# num_arch_ok_12_24m                 -0.1846      0.004    -47.660      0.000      -0.192      -0.177
# status_max_archived_0_6_months     -0.0356      0.014     -2.539      0.011      -0.063      -0.008
# status_max_archived_0_24_months     0.2775      0.012     23.649      0.000       0.255       0.301
# sum_capital_paid_acct_0_12m       5.87e-07    1.7e-06      0.345      0.730   -2.75e-06    3.92e-06
# time_hours                         -0.0175      0.002    -11.199      0.000      -0.021      -0.014
# ===================================================================================================

# %% [markdown]
# #### We've identified that the variable 'sum_capital_paid_acct_0_12m' has a p-value of 0.729, which exceeds the threshold of 0.05. Therefore, this variable is not significant for predicting classes, and we should remove it.

# %% [markdown]
# ### Dropping the above found redundant variables from the train and test data based on multicollinearity and p-value significance for prediction

# %%
X_train1 = X_train1.drop(["sum_paid_inv_0_12m", "max_paid_inv_0_12m", "sum_capital_paid_acct_0_12m"], axis=1)
X_test1 = X_test1.drop(["sum_paid_inv_0_12m", "max_paid_inv_0_12m", "sum_capital_paid_acct_0_12m"], axis=1)

# %% [markdown]
# #### Building the logit model again

# %%
X_train2 = sm.add_constant(X_train1)  # Adding a constant term (intercept)

# %%
X_test2 = sm.add_constant(X_test1)

# %%
logit_model = sm.Logit(y_res, X_train2)  
result_lgr = logit_model.fit()

print(result_lgr.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.508423
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                default   No. Observations:               115365
# Model:                          Logit   Df Residuals:                   115354
# Method:                           MLE   Df Model:                           10
# Date:                Sun, 05 May 2024   Pseudo R-squ.:                  0.2451
# Time:                        12:07:55   Log-Likelihood:                -58654.
# converged:                       True   LL-Null:                       -77698.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                               0.2822      0.038      7.377      0.000       0.207       0.357
# acct_amt_added_12_24m            3.364e-05   1.49e-06     22.629      0.000    3.07e-05    3.66e-05
# age                                -0.0268      0.001    -44.396      0.000      -0.028      -0.026
# avg_payment_span_0_12m              0.0606      0.001     43.708      0.000       0.058       0.063
# max_paid_inv_0_24m              -7.561e-05   1.64e-06    -46.137      0.000   -7.88e-05   -7.24e-05
# num_active_inv                      0.7085      0.012     60.548      0.000       0.686       0.731
# num_arch_ok_0_12m                  -0.1707      0.004    -44.697      0.000      -0.178      -0.163
# num_arch_ok_12_24m                 -0.1846      0.004    -47.657      0.000      -0.192      -0.177
# status_max_archived_0_6_months     -0.0359      0.014     -2.574      0.010      -0.063      -0.009
# status_max_archived_0_24_months     0.2783      0.011     24.246      0.000       0.256       0.301
# time_hours                         -0.0175      0.002    -11.202      0.000      -0.021      -0.014
# ===================================================================================================

# %% [markdown]
# #### After addressing multicollinearity, these 10 variables remain as the final significant variables, as all of them have p-values below 0.05.

# %% [markdown]
# ### Predicting on Training and Test data using the trained logistic regression model:

# %%
train_pred_lgr = result_lgr.predict(X_train2)
test_pred_lgr = result_lgr.predict(X_test2)

# %% [markdown]
# * Selecting the optimal threshold involves determining a probability threshold that effectively balances the trade-off between the true positive rate (TPR) and the false positive rate (FPR) of the model. The default threshold value is typically set at 0.5.

# %%
y_class_train_pred=[]   # Getting the Predicted Classes
for p in range(0,len(train_pred_lgr)):
    if np.array(train_pred_lgr)[p]>0.5:
        a=1
    else:
        a=0
    y_class_train_pred.append(a)

# %%
y_class_test_pred=[]
for p in range(0,len(test_pred_lgr)):
    if np.array(test_pred_lgr)[p]>0.5:
        a=1
    else:
        a=0
    y_class_test_pred.append(a)

# %% [markdown]
# #### Classification report for the train and test data:

# %%
print('classification_report for train data:')
print('------------------------------------')
print(metrics.classification_report(y_res,y_class_train_pred))
print('======================================================\n')
print('classification_report for test data:')
print('-----------------------------------')
print(metrics.classification_report(y_test,y_class_test_pred))
# Out:
# classification_report for train data:
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.79      0.79     69081
#          1.0       0.68      0.67      0.67     46284
#
#     accuracy                           0.74    115365
#    macro avg       0.73      0.73      0.73    115365
# weighted avg       0.74      0.74      0.74    115365
#
# ======================================================
#
# classification_report for test data:
# -----------------------------------
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.80      0.89     29608
#          1.0       0.04      0.70      0.08       386
#
#     accuracy                           0.80     29994
#    macro avg       0.52      0.75      0.48     29994
# weighted avg       0.98      0.80      0.88     29994

# %% [markdown]
# * The model is exhibiting slight signs of underfitting, indicated by a slight increase in the recall parameter for the test data compared to the train data.
# * Additionally, the trained model's performance is not satisfactory, particularly regarding the recall parameter for class 1, which is somewhat low. Therefore, we aim to further tune the model to improve its performance.

# %% [markdown]
# ----

# %% [markdown]
# ### Model tuning using Performance Metrics based on optimum cut-off (threshold value):

# %%
fpr, tpr, thresholds = roc_curve(y_res, train_pred_lgr)
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]
print('The optimum Cut-off value is:',optimal_threshold)
# Out:
# The optimum Cut-off value is: 0.4111007400051166

# %% [markdown]
# #### Getting predicted classes for train and test data on the optimum threshold of 0.4

# %%
y_class_train_pred=[]
for i in range(0,len(train_pred_lgr)):
    if np.array(train_pred_lgr)[i]>0.4:
        a=1
    else:
        a=0
    y_class_train_pred.append(a)

# %%
y_class_test_pred=[]
for i in range(0,len(test_pred_lgr)):
    if np.array(test_pred_lgr)[i]>0.4:
        a=1
    else:
        a=0
    y_class_test_pred.append(a)

# %% [markdown]
# #### Updated Classification report (lgr) for the train and test data:

# %%
print('Updated classification_report for train data:')
print('--------------------------------------------')
print(metrics.classification_report(y_res,y_class_train_pred))
print('======================================================\n')
print('Updated classification_report for test data:')
print('-------------------------------------------')
print(metrics.classification_report(y_test,y_class_test_pred))
# Out:
# Updated classification_report for train data:
# --------------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.68      0.75     69081
#          1.0       0.63      0.81      0.71     46284
#
#     accuracy                           0.73    115365
#    macro avg       0.73      0.74      0.73    115365
# weighted avg       0.75      0.73      0.73    115365
#
# ======================================================
#
# Updated classification_report for test data:
# -------------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.69      0.81     29608
#          1.0       0.03      0.81      0.06       386
#
#     accuracy                           0.69     29994
#    macro avg       0.51      0.75      0.44     29994
# weighted avg       0.98      0.69      0.80     29994

# %% [markdown]
# #### Updated Confusion matrix for the train data based on optimum threshold of 0.4:

# %%
sns.heatmap((metrics.confusion_matrix(y_res,y_class_train_pred)),annot=True,fmt='.5g'
            ,cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);

# %% [markdown]
# #### Updated Confusion matrix for the test data based on optimum threshold of 0.4:

# %%
sns.heatmap((metrics.confusion_matrix(y_test,y_class_test_pred)),annot=True,fmt='.5g'
            ,cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);

# %% [markdown]
# #### AUC and ROC for the train data:

# %%
# calculate AUC
train_auc = roc_auc_score(y_res, train_pred_lgr)
print('AUC for training data: %.3f' % train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_res, train_pred_lgr)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC for training data: 0.816

# %% [markdown]
# #### AUC and ROC for the testing data:

# %%
test_auc = roc_auc_score(y_test, test_pred_lgr)
print('AUC for testing data: %.3f' % test_auc)

test_fpr, test_tpr, test_thresholds = roc_curve(y_test, test_pred_lgr)
plt.plot([0, 1], [0, 1], linestyle='--')

plt.plot(test_fpr, test_tpr);
# Out:
# AUC for testing data: 0.829

# %% [markdown]
# -----

# %% [markdown]
# ---

# %% [markdown]
# ## 2.) LDA(Linear Discriminant Analysis) Model:

# %% [markdown]
# #### Training the LDA model using the train data:

# %%
clf = LinearDiscriminantAnalysis()
lda_model=clf.fit(X_train1,y_res)

# %% [markdown]
# #### Generating Coefficients and intercept for the Linear Discriminant Function:

# %%
print('The intercept value for the linear discriminant function is:',np.round(clf.intercept_,2))
# Out:
# The intercept value for the linear discriminant function is: [0.23]

# %%
print('Coefficients for the Linear Discriminant Function are:\n\n',np.round(clf.coef_,2))
# Out:
# Coefficients for the Linear Discriminant Function are:
#
#  [[ 0.   -0.03  0.06 -0.    0.65 -0.1  -0.1  -0.25  0.27 -0.02]]

# %%
X_train1.columns
# Out:
# Index(['acct_amt_added_12_24m', 'age', 'avg_payment_span_0_12m',
#        'max_paid_inv_0_24m', 'num_active_inv', 'num_arch_ok_0_12m',
#        'num_arch_ok_12_24m', 'status_max_archived_0_6_months',
#        'status_max_archived_0_24_months', 'time_hours'],
#       dtype='object')

# %% [markdown]
# **The Linear Discriminant Function is as follows:**
# LDF = 0.23 + (0 x acct_amt_added_12_24m) + (-0.03 x age) + (0.06 x avg_payment_span_0_12m) + (-0 x max_paid_inv_0_24m) + (0.65 x num_active_inv) + (-0.1 x num_arch_ok_0_12m) + (-0.25 x num_arch_ok_12_24m) + (0.27 x status_max_archived_0_6_months)+ (-0.02 x time_hours)

# %% [markdown]
# #### Predicting on Train and Test data using the trained LDA model:

# %%
train_pred_lda = lda_model.predict(X_train1)
test_pred_lda = lda_model.predict(X_test1)

# %% [markdown]
# #### Classification report for the train and test data:

# %%
print('classification_report for train data:')
print('------------------------------------')
print(metrics.classification_report(y_res,train_pred_lda))
print('======================================================\n')
print('classification_report for test data:')
print('-----------------------------------')
print(metrics.classification_report(y_test,test_pred_lda))
# Out:
# classification_report for train data:
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.79      0.78     69081
#          1.0       0.68      0.66      0.67     46284
#
#     accuracy                           0.74    115365
#    macro avg       0.73      0.73      0.73    115365
# weighted avg       0.74      0.74      0.74    115365
#
# ======================================================
#
# classification_report for test data:
# -----------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.79      0.88     29608
#          1.0       0.04      0.68      0.08       386
#
#     accuracy                           0.79     29994
#    macro avg       0.52      0.74      0.48     29994
# weighted avg       0.98      0.79      0.87     29994

# %% [markdown]
# ### Model tuning using Hyper-parameters optimisation:

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid = {
    'solver': ['lsqr', 'eigen'],  # Solvers for covariance estimation
    'shrinkage': [None, 'auto', 0.1, 0.5, 0.9],  # Shrinkage parameter (if solver='lsqr')
    'n_components': [None, 1, 2, 3],  # Number of components to keep
}

# %%
grid_search = GridSearchCV(estimator = lda_model, param_grid = grid, cv = 5,scoring='accuracy',n_jobs=-1)

# %%
grid_search.fit(X_train1, y_res)
# Out:
# GridSearchCV(cv=5, estimator=LinearDiscriminantAnalysis(), n_jobs=-1,
#              param_grid={'n_components': [None, 1, 2, 3],
#                          'shrinkage': [None, 'auto', 0.1, 0.5, 0.9],
#                          'solver': ['lsqr', 'eigen']},
#              scoring='accuracy')

# %%
print(grid_search.best_params_,'\n')
print(grid_search.best_estimator_)
# Out:
# {'n_components': None, 'shrinkage': 'auto', 'solver': 'lsqr'}
#
# LinearDiscriminantAnalysis(shrinkage='auto', solver='lsqr')

# %%
lda_best_model = grid_search.best_estimator_

# %%
train_pred_lda_best = lda_best_model.predict(X_train1)
test_pred_lda_best = lda_best_model.predict(X_test1)

# %%
print('classification_report for train data:')
print('------------------------------------')
print(metrics.classification_report(y_res,train_pred_lda_best))
print('======================================================\n')
print('classification_report for test data:')
print('-----------------------------------')
print(metrics.classification_report(y_test,test_pred_lda_best))
# Out:
# classification_report for train data:
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.79      0.78     69081
#          1.0       0.68      0.66      0.67     46284
#
#     accuracy                           0.74    115365
#    macro avg       0.73      0.73      0.73    115365
# weighted avg       0.74      0.74      0.74    115365
#
# ======================================================
#
# classification_report for test data:
# -----------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.79      0.88     29608
#          1.0       0.04      0.68      0.08       386
#
#     accuracy                           0.79     29994
#    macro avg       0.52      0.74      0.48     29994
# weighted avg       0.98      0.79      0.87     29994

# %% [markdown]
# #### Getting the Predicted Classes and Probabilities:

# %%
train_probs_lda_best = lda_best_model.predict_proba(X_train1)[:,1]   # keep probabilities for the positive outcome only
test_probs_lda_best = lda_best_model.predict_proba(X_test1)[:,1]

# %% [markdown]
# ### Model tuning using Performance Metrics based on optimum cut-off (threshold value):

# %% [markdown]
# #### Choosing the optimal threshold

# %%
fpr, tpr, thresholds = roc_curve(y_res, train_probs_lda_best)
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]
print('The optimum Cut-off value is:',optimal_threshold)
# Out:
# The optimum Cut-off value is: 0.39495382786703886

# %% [markdown]
# #### Updated Confusion matrix for the train and test data based on optimum cut-off of 0.395:

# %%
y_class_train_pred=[]
for i in range(0,len(train_probs_lda_best)):
    if np.array(train_probs_lda_best)[i]>0.395:
        a=1
    else:
        a=0
    y_class_train_pred.append(a)

# %%
sns.heatmap((metrics.confusion_matrix(y_res,y_class_train_pred)),annot=True,fmt='.5g'
            ,cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);

# %% [markdown]
# #### Updated Confusion matrix for the test data based on optimum cut-off of 0.395:

# %%
y_class_test_pred=[]
for i in range(0,len(test_probs_lda_best)):
    if np.array(test_probs_lda_best)[i]>0.395:
        a=1
    else:
        a=0
    y_class_test_pred.append(a)

# %%
sns.heatmap((metrics.confusion_matrix(y_test,y_class_test_pred)),annot=True,fmt='.5g'
            ,cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);

# %% [markdown]
# #### Updated Classification report (LDA) for the train and test data:

# %%
print('Updated classification_report for train data:')
print('--------------------------------------------')
print(metrics.classification_report(y_res,y_class_train_pred))
print('======================================================\n')
print('Updated classification_report for test data:')
print('-------------------------------------------')
print(metrics.classification_report(y_test,y_class_test_pred))
# Out:
# Updated classification_report for train data:
# --------------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.66      0.74     69081
#          1.0       0.62      0.82      0.70     46284
#
#     accuracy                           0.72    115365
#    macro avg       0.73      0.74      0.72    115365
# weighted avg       0.75      0.72      0.72    115365
#
# ======================================================
#
# Updated classification_report for test data:
# -------------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.66      0.80     29608
#          1.0       0.03      0.82      0.06       386
#
#     accuracy                           0.67     29994
#    macro avg       0.51      0.74      0.43     29994
# weighted avg       0.98      0.67      0.79     29994

# %% [markdown]
# #### AUC and ROC for the train data:

# %%
# calculate AUC
train_auc = roc_auc_score(y_res, train_probs_lda_best)
print('AUC for training data: %.3f' % train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_res, train_probs_lda_best)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC for training data: 0.811

# %% [markdown]
# #### AUC and ROC for the testing data:

# %%
test_auc = roc_auc_score(y_test, test_probs_lda_best)
print('AUC for testing data: %.3f' % test_auc)

test_fpr, test_tpr, test_thresholds = roc_curve(y_test, test_probs_lda_best)
plt.plot([0, 1], [0, 1], linestyle='--')

plt.plot(test_fpr, test_tpr);
# Out:
# AUC for testing data: 0.827

# %% [markdown]
# -----

# %% [markdown]
# ----

# %% [markdown]
# ## 3.) Bagging

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier


bag_model = BaggingClassifier(base_estimator= RandomForestClassifier(),n_estimators=50,random_state=1)

bag_model.fit(X_train1, y_res)
# Out:
# BaggingClassifier(base_estimator=RandomForestClassifier(), n_estimators=50,
#                   random_state=1)

# %% [markdown]
# #### Predicting on Train and Test data using the trained Bagging model with Random Forest as the base Estimator:

# %%
train_pred_bag = bag_model.predict(X_train1)
test_pred_bag = bag_model.predict(X_test1)

# %% [markdown]
# ### Now checking the model performance on train and test data:

# %% [markdown]
# #### Model performance (Bag_rf) on the Train and Test Data

# %%
print('train data:')
print('-----------')
print(metrics.classification_report(y_res, train_pred_bag))
print('======================================================')
print('test data:')
print('----------')
print(metrics.classification_report(y_test,test_pred_bag))
# Out:
# train data:
# -----------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99     69081
#          1.0       0.98      0.99      0.99     46284
#
#     accuracy                           0.99    115365
#    macro avg       0.99      0.99      0.99    115365
# weighted avg       0.99      0.99      0.99    115365
#
# ======================================================
# test data:
# ----------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.97      0.98     29608
#          1.0       0.05      0.10      0.07       386
#
#     accuracy                           0.96     29994
#    macro avg       0.52      0.54      0.52     29994
# weighted avg       0.98      0.96      0.97     29994

# %% [markdown]
# ### Tuning the base model based on optimum threshold value:

# %% [markdown]
# #### Getting the Predicted Classes and Probabilities:

# %%
train_probs_bag = bag_model.predict_proba(X_train1)[:,1]   # keep probabilities for the positive outcome only
test_probs_bag = bag_model.predict_proba(X_test1)[:,1]

# %% [markdown]
# ### Model tuning using Performance Metrics based on optimum cut-off (threshold value):

# %% [markdown]
# #### Choosing the optimal threshold

# %%
fpr, tpr, thresholds = roc_curve(y_res, train_probs_bag)
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]
print('The optimum Cut-off value is:',optimal_threshold)
# Out:
# The optimum Cut-off value is: 0.4138000000000001

# %% [markdown]
# #### Updated Confusion matrix for the train and test data based on optimum cut-off of 0.4:

# %%
y_class_train_pred=[]
for i in range(0,len(train_probs_bag)):
    if np.array(train_probs_bag)[i]>0.4:
        a=1
    else:
        a=0
    y_class_train_pred.append(a)

# %%
sns.heatmap((metrics.confusion_matrix(y_res,y_class_train_pred)),annot=True,fmt='.5g'
            ,cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);

# %% [markdown]
# #### Updated Confusion matrix for the test data based on optimum cut-off of 0.4:

# %%
y_class_test_pred=[]
for i in range(0,len(test_probs_bag)):
    if np.array(test_probs_bag)[i]>0.4:
        a=1
    else:
        a=0
    y_class_test_pred.append(a)

# %%
sns.heatmap((metrics.confusion_matrix(y_test,y_class_test_pred)),annot=True,fmt='.5g'
            ,cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);

# %% [markdown]
# #### Updated Classification report for the train and test data:

# %%
print('Updated classification_report for train data:')
print('--------------------------------------------')
print(metrics.classification_report(y_res,y_class_train_pred))
print('======================================================\n')
print('Updated classification_report for test data:')
print('-------------------------------------------')
print(metrics.classification_report(y_test,y_class_test_pred))
# Out:
# Updated classification_report for train data:
# --------------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.98      0.99     69081
#          1.0       0.98      1.00      0.99     46284
#
#     accuracy                           0.99    115365
#    macro avg       0.99      0.99      0.99    115365
# weighted avg       0.99      0.99      0.99    115365
#
# ======================================================
#
# Updated classification_report for test data:
# -------------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.96      0.98     29608
#          1.0       0.04      0.13      0.07       386
#
#     accuracy                           0.95     29994
#    macro avg       0.52      0.55      0.52     29994
# weighted avg       0.98      0.95      0.96     29994

# %% [markdown]
# #### AUC and ROC for the train data:

# %%
# predict probabilities
probs = bag_model.predict_proba(X_train1)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
train_auc = roc_auc_score(y_res, probs)
print('AUC for training data: %.3f' % train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_res, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC for training data: 0.999

# %% [markdown]
# #### AUC and ROC for the test data:

# %%
# predict probabilities
probs = bag_model.predict_proba(X_test1)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
test_auc = roc_auc_score(y_test, probs)
print('AUC for testing data: %.3f' % test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC for testing data: 0.789

# %% [markdown]
# ## 4.) Boosting

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %% [markdown]
# ## 4.a) ADA Boosting

# %%
adaboost_model = AdaBoostClassifier(random_state=1)
adaboost_model.fit(X_train1,y_res)
# Out:
# AdaBoostClassifier(random_state=1)

# %% [markdown]
# #### Predicting on Train and Test data using the trained Naive Bayes model:

# %%
train_pred_ada = adaboost_model.predict(X_train1)
test_pred_ada = adaboost_model.predict(X_test1)

# %% [markdown]
# #### Getting the Predicted Classes and Probabilities:

# %% [markdown]
# ### Now checking the model performance on train and test data:

# %% [markdown]
# #### Model performance (ada_boost) on the Train and Test Data

# %%
print('train data:\n===========\n')
print('Accuracy score on training data:\n-------------------------------\n', 
      adaboost_model.score(X_train1, y_res))
print('\n')
print('Classification Report:\n----------------------\n', 
      metrics.classification_report(y_res, train_pred_ada))

print('\n')

print('test data:\n===========\n')
print('Accuracy score on testing data:\n-------------------------------\n', 
      adaboost_model.score(X_test1, y_test))
print('\n')
print('Classification Report:\n----------------------\n', 
      metrics.classification_report(y_test, test_pred_ada))
# Out:
# train data:
# ===========
#
# Accuracy score on training data:
# -------------------------------
#  0.8394313699995666
#
#
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.85      0.86     69081
#          1.0       0.79      0.82      0.80     46284
#
#     accuracy                           0.84    115365
#    macro avg       0.83      0.84      0.83    115365
# weighted avg       0.84      0.84      0.84    115365
#
#
#
# test data:
# ===========
#
# Accuracy score on testing data:
# -------------------------------
#  0.8460692138427686
#
#
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#          0.0       0.99      0.85      0.92     29608
#          1.0       0.04      0.53      0.08       386
#
#     accuracy                           0.85     29994
#    macro avg       0.52      0.69      0.50     29994
# weighted avg       0.98      0.85      0.91     29994

# %% [markdown]
# ### Model Tuning:

# %%
adaboost_model.get_params().keys()
# Out:
# dict_keys(['algorithm', 'base_estimator', 'estimator', 'learning_rate', 'n_estimators', 'random_state'])

# %%
grid={'n_estimators': [30, 50, 70],
    'learning_rate':[0.01,0.1,1],
     'algorithm': ['SAMME', 'SAMME.R']}

# %%
grid_search = GridSearchCV(estimator = adaboost_model, param_grid = grid, cv = 7, n_jobs=-1)

# %%
grid_search.fit(X_train1, y_res)
# Out:
# GridSearchCV(cv=7, estimator=AdaBoostClassifier(random_state=1), n_jobs=-1,
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.01, 0.1, 1],
#                          'n_estimators': [30, 50, 70]})

# %%
print(grid_search.best_params_,'\n')
print(grid_search.best_estimator_)
# Out:
# {'algorithm': 'SAMME.R', 'learning_rate': 1, 'n_estimators': 70}
#
# AdaBoostClassifier(learning_rate=1, n_estimators=70, random_state=1)

# %%
ada_best_model = grid_search.best_estimator_

# %%
train_pred_ada_best = ada_best_model.predict(X_train1)
test_pred_ada_best = ada_best_model.predict(X_test1)

# %% [markdown]
# ### Now checking the model performance on train and test data:

# %% [markdown]
# #### Model performance (ada_boost) on the Train and Test Data

# %%
print('train data:')
print('-----------')
print(metrics.classification_report(y_res, train_pred_ada_best))
print('======================================================')
print('test data:')
print('----------')
print(metrics.classification_report(y_test,test_pred_ada_best))
# Out:
# train data:
# -----------
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.88      0.87     69081
#          1.0       0.81      0.80      0.81     46284
#
#     accuracy                           0.85    115365
#    macro avg       0.84      0.84      0.84    115365
# weighted avg       0.85      0.85      0.85    115365
#
# ======================================================
# test data:
# ----------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.88      0.93     29608
#          1.0       0.05      0.45      0.08       386
#
#     accuracy                           0.87     29994
#    macro avg       0.52      0.67      0.51     29994
# weighted avg       0.98      0.87      0.92     29994

# %% [markdown]
# #### Getting the Predicted Classes and Probabilities:

# %%
train_probs_ada = adaboost_model.predict_proba(X_train1)[:,1]   # keep probabilities for the positive outcome only
test_probs_ada = adaboost_model.predict_proba(X_test1)[:,1]

# %% [markdown]
# ### Model tuning using Performance Metrics based on optimum cut-off (threshold value):

# %% [markdown]
# #### Choosing the optimal threshold

# %%
fpr, tpr, thresholds = roc_curve(y_res, train_probs_ada)
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]
print('The optimum Cut-off value is:',optimal_threshold)
# Out:
# The optimum Cut-off value is: 0.49800732065585496

# %% [markdown]
# #### Updated Confusion matrix for the train data based on optimum cut-off of 0.498:

# %%
y_class_train_pred=[]
for i in range(0,len(train_probs_ada)):
    if np.array(train_probs_ada)[i]>0.498:
        a=1
    else:
        a=0
    y_class_train_pred.append(a)

# %%
sns.heatmap((metrics.confusion_matrix(y_res,y_class_train_pred)),annot=True,fmt='.5g'
            ,cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);

# %% [markdown]
# #### Updated Confusion matrix for the test data based on optimum cut-off of 0.498:

# %%
y_class_test_pred=[]
for i in range(0,len(test_probs_ada)):
    if np.array(test_probs_ada)[i]>0.498:
        a=1
    else:
        a=0
    y_class_test_pred.append(a)

# %%
sns.heatmap((metrics.confusion_matrix(y_test,y_class_test_pred)),annot=True,fmt='.5g'
            ,cmap='Blues');
plt.xlabel('Predicted');
plt.ylabel('Actuals',rotation=0);

# %% [markdown]
# #### Updated Classification report for the train and test data:

# %%
print('Updated classification_report for train data:')
print('--------------------------------------------')
print(metrics.classification_report(y_res,y_class_train_pred))
print('======================================================\n')
print('Updated classification_report for test data:')
print('-------------------------------------------')
print(metrics.classification_report(y_test,y_class_test_pred))
# Out:
# Updated classification_report for train data:
# --------------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.80      0.86     69081
#          1.0       0.75      0.90      0.82     46284
#
#     accuracy                           0.84    115365
#    macro avg       0.84      0.85      0.84    115365
# weighted avg       0.85      0.84      0.84    115365
#
# ======================================================
#
# Updated classification_report for test data:
# -------------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.80      0.89     29608
#          1.0       0.04      0.65      0.08       386
#
#     accuracy                           0.80     29994
#    macro avg       0.52      0.72      0.48     29994
# weighted avg       0.98      0.80      0.88     29994

# %% [markdown]
# #### AUC and ROC for the tuned train data:

# %%
# predict probabilities
probs = ada_best_model.predict_proba(X_train1)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
train_auc = roc_auc_score(y_res, probs)
print('AUC for training data: %.3f' % train_auc)
# calculate roc curve
train_fpr, train_tpr, train_thresholds = roc_curve(y_res, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(train_fpr, train_tpr);
# Out:
# AUC for training data: 0.941

# %% [markdown]
# #### AUC and ROC for the tuned test data:

# %%
# predict probabilities
probs = ada_best_model.predict_proba(X_test1)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
test_auc = roc_auc_score(y_test, probs)
print('AUC for testing data: %.3f' % test_auc)
# calculate roc curve
test_fpr, test_tpr, test_thresholds = roc_curve(y_test, probs)
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(test_fpr, test_tpr);
# Out:
# AUC for testing data: 0.813

# %% [markdown]
# #### Feature importances for ADA Boosting model:

# %%
print (pd.DataFrame(adaboost_model.feature_importances_, columns = ["Imp"], index = X_train1.columns).sort_values('Imp',ascending=False))
# Out:
#                                  Imp
# num_active_inv                  0.34
# status_max_archived_0_24_months 0.20
# status_max_archived_0_6_months  0.16
# num_arch_ok_0_12m               0.08
# num_arch_ok_12_24m              0.08
# age                             0.04
# max_paid_inv_0_24m              0.04
# time_hours                      0.04
# avg_payment_span_0_12m          0.02
# acct_amt_added_12_24m           0.00

# %% [markdown]
# ----

# %% [markdown]
# ----
